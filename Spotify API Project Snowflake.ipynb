# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_credentials_manager = SpotifyClientCredentials(client_id = '', client_secret = '')

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = 'https://open.spotify.com/playlist/6VOedaf3eNWDOVpa9Qdlvg'

# %%
playlist_uri = playlist_link.split('/')[-1]

# %%
data = sp.playlist_tracks(playlist_uri)

# %%
data['items'][0]['track']['album']['id']
# Out:
# '6xUYw5goKIoyJQi9C27UBy'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'NUNCA MUDA?'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2025-01-09'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 6

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/6xUYw5goKIoyJQi9C27UBy'

# %%
album_list = []
for i in data['items']:
    album_id = i['track']['album']['id']
    album_name = i['track']['album']['name']
    album_release_date = i['track']['album']['release_date']
    album_total_tracks = i['track']['album']['total_tracks']
    album_url = i['track']['album']['external_urls']['spotify']
    album_elements = {'album_id':album_id,'album_name':album_name,'release_date':album_release_date,'total_tracks':album_total_tracks,'url':album_url}
    
    album_list.append(album_elements)

# %%
album_list
# Out:
# [{'album_id': '6xUYw5goKIoyJQi9C27UBy',
#   'album_name': 'NUNCA MUDA?',
#   'release_date': '2025-01-09',
#   'total_tracks': 6,
#   'url': 'https://open.spotify.com/album/6xUYw5goKIoyJQi9C27UBy'},
#  {'album_id': '5D17Gk0J7jPXLvWMszqijF',
#   'album_name': 'MONTAGEM TOMADA',
#   'release_date': '2025-03-21',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/5D17Gk0J7jPXLvWMszqijF'},
#  {'album_id': '1kmsUHDC0n611meNgzRkuw',
#   'album_name': 'FUNK UNIVERSO',
#   'release_date': '2024-07-03',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/1kmsUHDC0n611meNgzRkuw'},
#  {'album_id': '3Aw43kkDlLE5ZXwQPGHWgO',
#   'album_name': 'MONTAGEM LADRAO',
#   'release_date': '2025-02-05',
#   'total_tracks': 5,
#   'url': 'https://open.spotify.com/album/3Aw43kkDlLE5ZXwQPGHWgO'},
#  {'album_id': '62R2H85ZiKLp0lYHPprQWV',
#   'album_name': 'MTG - RITMO ZELDA',
#   'release_date': '2024-06-28',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/62R2H85ZiKLp0lYHPprQWV'},
#  {'album_id': '4s7LxMlh6RxgdMhldfMe8u',
#   'album_name': 'Funk de Beleza',
#   'release_date': '2024-10-04',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/4s7LxMlh6RxgdMhldfMe8u'},
#  {'album_id': '572YC1K4uc7PjFqb6xaICD',
#   'album_name': 'BOUNCE FUNK (Slowed)',
#   'release_date': '2025-02-15',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/572YC1K4uc7PjFqb6xaICD'},
#  {'album_id': '4FRxgE6LA2UGJ5yz8diaI9',
#   'album_name': 'FUNKED UP',
#   'release_date': '2024-01-19',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/4FRxgE6LA2UGJ5yz8diaI9'},
#  {'album_id': '3tSeUNn7yOQPEex7jwS9Bf',
#   'album_name': 'GLORY',
#   'release_date': '2024-05-24',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/3tSeUNn7yOQPEex7jwS9Bf'},
#  {'album_id': '6YLJD87ZAaFBziGObBIcOW',
#   'album_name': 'EMPIRE',
#   'release_date': '2024-08-02',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/6YLJD87ZAaFBziGObBIcOW'},
#  {'album_id': '06a7H7nusNMvM7yL8m3fy1',
#   'album_name': 'AURA',
#   'release_date': '2024-07-12',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/06a7H7nusNMvM7yL8m3fy1'},
#  {'album_id': '6Zd0Hg3HKVH7xhBPgESQy1',
#   'album_name': 'FUNK DO BOUNCE (Slowed)',
#   'release_date': '2024-08-30',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6Zd0Hg3HKVH7xhBPgESQy1'},
#  {'album_id': '1dNr9lYDxO0pyG6poLIVWA',
#   'album_name': 'hypnotic',
#   'release_date': '2024-05-31',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/1dNr9lYDxO0pyG6poLIVWA'},
#  {'album_id': '1QFKbF3Oot9Ad1NnRCAG32',
#   'album_name': 'X-SLIDE',
#   'release_date': '2024-05-10',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/1QFKbF3Oot9Ad1NnRCAG32'},
#  {'album_id': '4QmDrxVGw99LUJOubfPJz9',
#   'album_name': 'SPOOKY',
#   'release_date': '2024-10-24',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/4QmDrxVGw99LUJOubfPJz9'},
#  {'album_id': '6dNugoBYWvUDQDtLurImhw',
#   'album_name': 'X-TALI',
#   'release_date': '2024-08-23',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6dNugoBYWvUDQDtLurImhw'},
#  {'album_id': '51F5iHYpECc8dd9Wjqv15o',
#   'album_name': 'Eu Sento Gabu!',
#   'release_date': '2024-04-19',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/51F5iHYpECc8dd9Wjqv15o'},
#  {'album_id': '1qlnjo9SZtK01FqDyjv6nM',
#   'album_name': 'EI DO SENSACIO!',
#   'release_date': '2024-07-29',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/1qlnjo9SZtK01FqDyjv6nM'},
#  {'album_id': '5rDznSixlUXNxJySfWQNb7',
#   'album_name': 'REI DO BRASIL',
#   'release_date': '2023-06-02',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5rDznSixlUXNxJySfWQNb7'},
#  {'album_id': '6s28IiIJ7ElbJfTPn03D6Y',
#   'album_name': 'THOMAS',
#   'release_date': '2024-04-12',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6s28IiIJ7ElbJfTPn03D6Y'},
#  {'album_id': '1vQpZhp0nRdlUT4m2cgV4k',
#   'album_name': 'Mexican Phonk Eki',
#   'release_date': '2023-06-23',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/1vQpZhp0nRdlUT4m2cgV4k'},
#  {'album_id': '3I0PQFWT0lGD5zWcGHwbRW',
#   'album_name': 'PLANETA DESCONHECIDO',
#   'release_date': '2024-01-26',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/3I0PQFWT0lGD5zWcGHwbRW'},
#  {'album_id': '1XFONq6J523aOBZDsjtCW8',
#   'album_name': 'Louca Encubada',
#   'release_date': '2023-10-13',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1XFONq6J523aOBZDsjtCW8'},
#  {'album_id': '0FNQKStah5NuLZu0Npw17w',
#   'album_name': 'A-What',
#   'release_date': '2024-06-21',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/0FNQKStah5NuLZu0Npw17w'},
#  {'album_id': '3Ar02fcnzPDg1xvy05pWff',
#   'album_name': 'Se Paciente Funk',
#   'release_date': '2024-07-26',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/3Ar02fcnzPDg1xvy05pWff'},
#  {'album_id': '2i9lYE2CWNBLmDiXwJ884n',
#   'album_name': 'EL QUE LA DEBE FUNK',
#   'release_date': '2024-11-06',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/2i9lYE2CWNBLmDiXwJ884n'},
#  {'album_id': '6mfljhxeSViWr01HscxHjS',
#   'album_name': 'BAD PARENTING FUNK V2',
#   'release_date': '2024-10-21',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/6mfljhxeSViWr01HscxHjS'},
#  {'album_id': '5n9EF7hP2GRMiklzLpPY0E',
#   'album_name': 'AVANGARD (Slowed)',
#   'release_date': '2024-08-02',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5n9EF7hP2GRMiklzLpPY0E'},
#  {'album_id': '3ra1kh1AmwAFm1jg9dwONE',
#   'album_name': 'JOGO DE TOLOS',
#   'release_date': '2024-09-13',
#   'total_tracks': 5,
#   'url': 'https://open.spotify.com/album/3ra1kh1AmwAFm1jg9dwONE'},
#  {'album_id': '1Wr2LyF0JSHHPv9nGXgFTN',
#   'album_name': 'O Melhor no Que Faz 3.0 [Slowed]',
#   'release_date': '2024-07-22',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1Wr2LyF0JSHHPv9nGXgFTN'},
#  {'album_id': '7JslfZtjZ430btdARyxLQ4',
#   'album_name': 'PYTHON FUNK',
#   'release_date': '2024-08-23',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/7JslfZtjZ430btdARyxLQ4'},
#  {'album_id': '2Osz2h7ZjKHOZh5grL7o6G',
#   'album_name': 'BAIXO',
#   'release_date': '2023-09-19',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2Osz2h7ZjKHOZh5grL7o6G'},
#  {'album_id': '7EWDvEG6vKIjTBk3rGMtP0',
#   'album_name': 'BRODYAGA FUNK',
#   'release_date': '2023-11-17',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/7EWDvEG6vKIjTBk3rGMtP0'},
#  {'album_id': '0cpfgDzjHZuYfiBc7jPsn6',
#   'album_name': 'Funk of Galáctico',
#   'release_date': '2024-04-05',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/0cpfgDzjHZuYfiBc7jPsn6'},
#  {'album_id': '1k9oQsBjwIhc4vF32zxvY5',
#   'album_name': 'NEXT!',
#   'release_date': '2024-06-07',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/1k9oQsBjwIhc4vF32zxvY5'},
#  {'album_id': '5eRHyCycBt78BNaa8vR4Si',
#   'album_name': 'FRESH',
#   'release_date': '2023-02-24',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5eRHyCycBt78BNaa8vR4Si'},
#  {'album_id': '2RhX80u97LacDUbFoSLT5W',
#   'album_name': 'MONTAGEM BRAVO',
#   'release_date': '2024-11-29',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/2RhX80u97LacDUbFoSLT5W'},
#  {'album_id': '27XmqsKeLyr5jDURAordcd',
#   'album_name': 'TUCA DONKA',
#   'release_date': '2023-07-28',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/27XmqsKeLyr5jDURAordcd'},
#  {'album_id': '6DptPhwLku8xvWBodULnC6',
#   'album_name': 'Orquestra Maldita',
#   'release_date': '2023-06-15',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6DptPhwLku8xvWBodULnC6'},
#  {'album_id': '1ILssfrknV8cQv5QvwBGUY',
#   'album_name': 'DNA',
#   'release_date': '2023-12-21',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/1ILssfrknV8cQv5QvwBGUY'},
#  {'album_id': '6tf2ziKDZQJinItJi99wBW',
#   'album_name': 'SPACE!',
#   'release_date': '2024-04-26',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/6tf2ziKDZQJinItJi99wBW'},
#  {'album_id': '3BsuqyYCV0DYIBrDi1SKwQ',
#   'album_name': 'Sequência da Dz7',
#   'release_date': '2023-05-07',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3BsuqyYCV0DYIBrDi1SKwQ'},
#  {'album_id': '2EuOCirl08WxbRY2cfj4H5',
#   'album_name': 'Life in Rio',
#   'release_date': '2023-03-17',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2EuOCirl08WxbRY2cfj4H5'},
#  {'album_id': '7cNqBJdXx8dgoXegihUPVN',
#   'album_name': 'Turu R9',
#   'release_date': '2024-04-01',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/7cNqBJdXx8dgoXegihUPVN'},
#  {'album_id': '3Iw0jAPzwgmuqSIWQa9i8W',
#   'album_name': 'FUNK INFERNAL',
#   'release_date': '2024-09-27',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3Iw0jAPzwgmuqSIWQa9i8W'},
#  {'album_id': '6la9ubAAPlhP8eylFPuLlC',
#   'album_name': 'Montagem Sonic Ritmado 1.0 (Slowed)',
#   'release_date': '2024-05-15',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6la9ubAAPlhP8eylFPuLlC'},
#  {'album_id': '1R1KJCX1oc3xqSbABo2Wpn',
#   'album_name': 'Montagem Injuriosum Retines (Slowed)',
#   'release_date': '2024-08-23',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1R1KJCX1oc3xqSbABo2Wpn'},
#  {'album_id': '1mEN4vjqXeZN9FmNzFLCBf',
#   'album_name': 'AUTOMOTIVO DA TURBULENCIA',
#   'release_date': '2024-10-08',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1mEN4vjqXeZN9FmNzFLCBf'},
#  {'album_id': '2bqWrlHmNh4M41xOr0p7iN',
#   'album_name': 'Funk Secreto (Ultra Slowed)',
#   'release_date': '2024-09-09',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2bqWrlHmNh4M41xOr0p7iN'},
#  {'album_id': '3HEJNpi4OtYpYQlGy2anVB',
#   'album_name': 'void',
#   'release_date': '2024-08-23',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/3HEJNpi4OtYpYQlGy2anVB'},
#  {'album_id': '74uo4Lv0VMyxdOjlf40y1T',
#   'album_name': 'FUNK ESTRANHO (SUPER SLOWED)',
#   'release_date': '2024-07-30',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/74uo4Lv0VMyxdOjlf40y1T'},
#  {'album_id': '5jXbkZ8fgtvq5OufR9LJz4',
#   'album_name': 'BLUE HORIZON FUNK',
#   'release_date': '2024-11-25',
#   'total_tracks': 5,
#   'url': 'https://open.spotify.com/album/5jXbkZ8fgtvq5OufR9LJz4'},
#  {'album_id': '7hNzImuUou9dBftesPXcAt',
#   'album_name': 'BLAH',
#   'release_date': '2025-02-13',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/7hNzImuUou9dBftesPXcAt'},
#  {'album_id': '1Idktx9vdSSkm1yxABycnf',
#   'album_name': 'DON`T STOP',
#   'release_date': '2024-04-19',
#   'total_tracks': 5,
#   'url': 'https://open.spotify.com/album/1Idktx9vdSSkm1yxABycnf'},
#  {'album_id': '3xCc8FxQsm6AE7ZWJ7h5sx',
#   'album_name': 'SLAY!',
#   'release_date': '2024-03-15',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/3xCc8FxQsm6AE7ZWJ7h5sx'},
#  {'album_id': '5rl2NDQDv9VpZLoEFOaYNg',
#   'album_name': 'MONTAGEM INVASÃO',
#   'release_date': '2024-03-21',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/5rl2NDQDv9VpZLoEFOaYNg'},
#  {'album_id': '09xRsRc7pX399wCGElOfMT',
#   'album_name': 'BRUXO FANTASMA',
#   'release_date': '2024-08-16',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/09xRsRc7pX399wCGElOfMT'},
#  {'album_id': '5tod76GzFMGREffztRiLyJ',
#   'album_name': 'Montagem Lunar Celestia 1.0 (SLOWED)',
#   'release_date': '2024-10-14',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5tod76GzFMGREffztRiLyJ'},
#  {'album_id': '5eEfzNcFaXPsBXJzkPiD3S',
#   'album_name': 'Beeper Funk (Slowed)',
#   'release_date': '2024-08-09',
#   'total_tracks': 2,
#   'url': 'https://open.spotify.com/album/5eEfzNcFaXPsBXJzkPiD3S'},
#  {'album_id': '6PZBt4XZvd1ElHAHG31J1j',
#   'album_name': 'FUNK DO BALKAN',
#   'release_date': '2024-10-18',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/6PZBt4XZvd1ElHAHG31J1j'},
#  {'album_id': '05EQpLFKhJ1m4YElm4zDHr',
#   'album_name': 'Ela Vira Mortal',
#   'release_date': '2022-08-05',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/05EQpLFKhJ1m4YElm4zDHr'},
#  {'album_id': '2R1AMmWGUa5IJYAdejtajq',
#   'album_name': 'O Melhor no Que Faz 3.0',
#   'release_date': '2024-06-27',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2R1AMmWGUa5IJYAdejtajq'},
#  {'album_id': '5Ide1hRSwzUYUnTQhq6CBv',
#   'album_name': 'Death Is No More',
#   'release_date': '2021-01-25',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5Ide1hRSwzUYUnTQhq6CBv'},
#  {'album_id': '4Fpr7mZ709qg0Iu1ESYNwz',
#   'album_name': 'SEQUÊNCIA MALÉFICA 1.0',
#   'release_date': '2024-02-19',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/4Fpr7mZ709qg0Iu1ESYNwz'},
#  {'album_id': '7Bc7xEWvkW01bvq5jAhCQS',
#   'album_name': 'YUM YUM',
#   'release_date': '2023-06-23',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/7Bc7xEWvkW01bvq5jAhCQS'},
#  {'album_id': '2DNOGCn0szoh9f3rAnhF7b',
#   'album_name': 'BAD PARENTING FUNK',
#   'release_date': '2024-10-22',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/2DNOGCn0szoh9f3rAnhF7b'},
#  {'album_id': '5hUTWbVLPE7Vo9KtS06U15',
#   'album_name': 'Cuando se te moja la tarea 2',
#   'release_date': '2024-06-21',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/5hUTWbVLPE7Vo9KtS06U15'},
#  {'album_id': '4ibsk1iPM7xDpJkNXREmsl',
#   'album_name': 'MANDA BALA',
#   'release_date': '2023-12-08',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/4ibsk1iPM7xDpJkNXREmsl'},
#  {'album_id': '4hBpayDWGOGsgnwFY8qm3G',
#   'album_name': 'FUNK OSCURO',
#   'release_date': '2024-10-24',
#   'total_tracks': 5,
#   'url': 'https://open.spotify.com/album/4hBpayDWGOGsgnwFY8qm3G'},
#  {'album_id': '5NJDkJdeVRTLpOJalNfb95',
#   'album_name': 'Montagem Bionica Espectral 2 (Slowed + Reverb)',
#   'release_date': '2024-07-24',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5NJDkJdeVRTLpOJalNfb95'},
#  {'album_id': '7lolzbhq4moSJPfFpdosl5',
#   'album_name': 'RISADA CHUCK 01',
#   'release_date': '2024-08-26',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/7lolzbhq4moSJPfFpdosl5'},
#  {'album_id': '47VSbmVnuMFiaFv3ZiK0Ee',
#   'album_name': 'ACIDO',
#   'release_date': '2024-10-31',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/47VSbmVnuMFiaFv3ZiK0Ee'},
#  {'album_id': '5J00ADHG1jlJiLjQDPURVh',
#   'album_name': 'ICEWHORE!',
#   'release_date': '2023-03-24',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5J00ADHG1jlJiLjQDPURVh'},
#  {'album_id': '28N1pcdMLhrEajfJKkBkl1',
#   'album_name': 'MONTAGEM DIAMANTE ROSA',
#   'release_date': '2024-01-09',
#   'total_tracks': 2,
#   'url': 'https://open.spotify.com/album/28N1pcdMLhrEajfJKkBkl1'},
#  {'album_id': '7DGsEVuwdKBKrzDx8fzEKn',
#   'album_name': 'MTG - VINGANÇA',
#   'release_date': '2024-01-26',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/7DGsEVuwdKBKrzDx8fzEKn'},
#  {'album_id': '6h4Lw0QisEuuAwmnMQvbse',
#   'album_name': 'VAPO NO SETOR',
#   'release_date': '2024-08-13',
#   'total_tracks': 5,
#   'url': 'https://open.spotify.com/album/6h4Lw0QisEuuAwmnMQvbse'},
#  {'album_id': '4cfBuRZw1az5lIdTYxuOPq',
#   'album_name': 'BIBI PHONK BR',
#   'release_date': '2023-08-25',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/4cfBuRZw1az5lIdTYxuOPq'},
#  {'album_id': '5mGMCvuF70Alfy0FXg3Sn7',
#   'album_name': 'x-tudo',
#   'release_date': '2024-01-25',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/5mGMCvuF70Alfy0FXg3Sn7'},
#  {'album_id': '0VnjSeajDjzh2mRdWePGhN',
#   'album_name': 'AREAMATE MIZ',
#   'release_date': '2023-08-28',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/0VnjSeajDjzh2mRdWePGhN'},
#  {'album_id': '4J0FEQtbjPH1DA60p6bKe9',
#   'album_name': 'YUMMI',
#   'release_date': '2023-10-02',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/4J0FEQtbjPH1DA60p6bKe9'},
#  {'album_id': '6tuTOSJX2SjH8JBsh5uM30',
#   'album_name': 'WHINE IN BRAZIL FUNK',
#   'release_date': '2024-07-09',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6tuTOSJX2SjH8JBsh5uM30'},
#  {'album_id': '58Uel2jPuFAf4bRiWHLYVz',
#   'album_name': 'MONTAGEM VOZES PROFUNDAS (TikTok Version)',
#   'release_date': '2024-07-12',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/58Uel2jPuFAf4bRiWHLYVz'},
#  {'album_id': '5T9u88WBOgCsGk3GT30Z3r',
#   'album_name': 'Bero 02',
#   'release_date': '2023-10-18',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5T9u88WBOgCsGk3GT30Z3r'},
#  {'album_id': '3D2j7JQjj9Kjc8sOfikmV6',
#   'album_name': 'Montagem Melodia Explosiva',
#   'release_date': '2024-09-06',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/3D2j7JQjj9Kjc8sOfikmV6'},
#  {'album_id': '43DSGSYCywacjEkdeSv4DC',
#   'album_name': 'MASHA ULTRAFUNK',
#   'release_date': '2024-03-07',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/43DSGSYCywacjEkdeSv4DC'},
#  {'album_id': '30Ytb0PG1tOv7JiKOTBK2v',
#   'album_name': 'Ela Joga na Hora',
#   'release_date': '2024-03-28',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/30Ytb0PG1tOv7JiKOTBK2v'},
#  {'album_id': '4QlnGetYxfXaVGhgdmF0vG',
#   'album_name': 'BRAZILIAN DANÇA PHONK',
#   'release_date': '2023-05-12',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/4QlnGetYxfXaVGhgdmF0vG'},
#  {'album_id': '6dRJ8zaG9oTGrwpfu0Itld',
#   'album_name': 'z-beta 2',
#   'release_date': '2025-01-03',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/6dRJ8zaG9oTGrwpfu0Itld'},
#  {'album_id': '2cuIEt1nONL2bu9HnSXjVT',
#   'album_name': 'Faz de Chicote',
#   'release_date': '2024-09-17',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2cuIEt1nONL2bu9HnSXjVT'},
#  {'album_id': '4yUHDMHDEl6Th3jPimciMz',
#   'album_name': 'MY TYPE',
#   'release_date': '2025-01-03',
#   'total_tracks': 5,
#   'url': 'https://open.spotify.com/album/4yUHDMHDEl6Th3jPimciMz'},
#  {'album_id': '0yr5YRR7l813mmHITxmFWa',
#   'album_name': 'BLOODY!',
#   'release_date': '2024-08-27',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/0yr5YRR7l813mmHITxmFWa'}]

# %%
data['items'][0]['track']['artists'][0]['id']
# Out:
# '5dDNNq04RjKXFOADdHd6VX'

# %%
data['items'][0]['track']['artists'][0]['name']
# Out:
# 'Scythermane'

# %%
data['items'][0]['track']['artists'][0]
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/5dDNNq04RjKXFOADdHd6VX'},
#  'href': 'https://api.spotify.com/v1/artists/5dDNNq04RjKXFOADdHd6VX',
#  'id': '5dDNNq04RjKXFOADdHd6VX',
#  'name': 'Scythermane',
#  'type': 'artist',
#  'uri': 'spotify:artist:5dDNNq04RjKXFOADdHd6VX'}

# %%
artist_list = []
for i in data['items']:
    for key,value in i.items():
        if key == 'track':
            for artist in value['artists']:
                artist_dict = {'artist_id':artist['id'],'artist_name':artist['name'],'external_url':artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '5dDNNq04RjKXFOADdHd6VX',
#   'artist_name': 'Scythermane',
#   'external_url': 'https://api.spotify.com/v1/artists/5dDNNq04RjKXFOADdHd6VX'},
#  {'artist_id': '7lAaAGxYxk2GH8cMbTEwAL',
#   'artist_name': 'NXGHT!',
#   'external_url': 'https://api.spotify.com/v1/artists/7lAaAGxYxk2GH8cMbTEwAL'},
#  {'artist_id': '14hsjenLEdvafsGkk2CEiF',
#   'artist_name': 'MC Fabinho da Osk',
#   'external_url': 'https://api.spotify.com/v1/artists/14hsjenLEdvafsGkk2CEiF'},
#  {'artist_id': '7kk9ucvRJim0NMM89Lml2Y',
#   'artist_name': 'MXZI',
#   'external_url': 'https://api.spotify.com/v1/artists/7kk9ucvRJim0NMM89Lml2Y'},
#  {'artist_id': '2vKxv2oKVSEJZ1VmuLUOvY',
#   'artist_name': 'Irokz',
#   'external_url': 'https://api.spotify.com/v1/artists/2vKxv2oKVSEJZ1VmuLUOvY'},
#  {'artist_id': '5SCDfg1YoEfI5gFtXqEWah',
#   'artist_name': 'ATLXS',
#   'external_url': 'https://api.spotify.com/v1/artists/5SCDfg1YoEfI5gFtXqEWah'},
#  {'artist_id': '7kk9ucvRJim0NMM89Lml2Y',
#   'artist_name': 'MXZI',
#   'external_url': 'https://api.spotify.com/v1/artists/7kk9ucvRJim0NMM89Lml2Y'},
#  {'artist_id': '6guLZyE3by1cVU1ydAAKpJ',
#   'artist_name': 'Itamar Mc',
#   'external_url': 'https://api.spotify.com/v1/artists/6guLZyE3by1cVU1ydAAKpJ'},
#  {'artist_id': '2nGwC9QG6Hpw4fSDgNpn5n',
#   'artist_name': 'JXM',
#   'external_url': 'https://api.spotify.com/v1/artists/2nGwC9QG6Hpw4fSDgNpn5n'},
#  {'artist_id': '4DWPOsGWbW7sBHb1UuBvWs',
#   'artist_name': 'Polaris',
#   'external_url': 'https://api.spotify.com/v1/artists/4DWPOsGWbW7sBHb1UuBvWs'},
#  {'artist_id': '3g0UoyvaTaHUrfpHiRqsD1',
#   'artist_name': 'Nateki',
#   'external_url': 'https://api.spotify.com/v1/artists/3g0UoyvaTaHUrfpHiRqsD1'},
#  {'artist_id': '5dDNNq04RjKXFOADdHd6VX',
#   'artist_name': 'Scythermane',
#   'external_url': 'https://api.spotify.com/v1/artists/5dDNNq04RjKXFOADdHd6VX'},
#  {'artist_id': '10mKIVPFtg42JIvttHQrzr',
#   'artist_name': 'MC MAYAH',
#   'external_url': 'https://api.spotify.com/v1/artists/10mKIVPFtg42JIvttHQrzr'},
#  {'artist_id': '0pSdNszQKrzI6m9okVVSL5',
#   'artist_name': 'SAPFIR',
#   'external_url': 'https://api.spotify.com/v1/artists/0pSdNszQKrzI6m9okVVSL5'},
#  {'artist_id': '4nl0CCx6PpEOOr2Z2ThPdp',
#   'artist_name': 'xxanteria',
#   'external_url': 'https://api.spotify.com/v1/artists/4nl0CCx6PpEOOr2Z2ThPdp'},
#  {'artist_id': '6JjQbtAO09K7qBEW2pdX5s',
#   'artist_name': 'isq',
#   'external_url': 'https://api.spotify.com/v1/artists/6JjQbtAO09K7qBEW2pdX5s'},
#  {'artist_id': '1Sdc6ySbIvzO0X9vbyHzWm',
#   'artist_name': 'Ogryzek',
#   'external_url': 'https://api.spotify.com/v1/artists/1Sdc6ySbIvzO0X9vbyHzWm'},
#  {'artist_id': '1Sdc6ySbIvzO0X9vbyHzWm',
#   'artist_name': 'Ogryzek',
#   'external_url': 'https://api.spotify.com/v1/artists/1Sdc6ySbIvzO0X9vbyHzWm'},
#  {'artist_id': '1Sdc6ySbIvzO0X9vbyHzWm',
#   'artist_name': 'Ogryzek',
#   'external_url': 'https://api.spotify.com/v1/artists/1Sdc6ySbIvzO0X9vbyHzWm'},
#  {'artist_id': '09cKncAQn28NqTUORLMwSR',
#   'artist_name': 'Ariis',
#   'external_url': 'https://api.spotify.com/v1/artists/09cKncAQn28NqTUORLMwSR'},
#  {'artist_id': '6JjQbtAO09K7qBEW2pdX5s',
#   'artist_name': 'isq',
#   'external_url': 'https://api.spotify.com/v1/artists/6JjQbtAO09K7qBEW2pdX5s'},
#  {'artist_id': '2vPnS0IpayC2RVFuQA08R4',
#   'artist_name': '2KE',
#   'external_url': 'https://api.spotify.com/v1/artists/2vPnS0IpayC2RVFuQA08R4'},
#  {'artist_id': '4jM6R2LK78dVTqHVUoA4li',
#   'artist_name': '808iuli',
#   'external_url': 'https://api.spotify.com/v1/artists/4jM6R2LK78dVTqHVUoA4li'},
#  {'artist_id': '5tvPbCrx8LMaL9Zby5e7c2',
#   'artist_name': 'fennecxx',
#   'external_url': 'https://api.spotify.com/v1/artists/5tvPbCrx8LMaL9Zby5e7c2'},
#  {'artist_id': '7FqHcUwnhxJZAgS3I6GFFL',
#   'artist_name': 'DJ ALEX',
#   'external_url': 'https://api.spotify.com/v1/artists/7FqHcUwnhxJZAgS3I6GFFL'},
#  {'artist_id': '7qIgmxSjoXEeifSVDh8nIt',
#   'artist_name': 'MXCCREE',
#   'external_url': 'https://api.spotify.com/v1/artists/7qIgmxSjoXEeifSVDh8nIt'},
#  {'artist_id': '1dX1zejt24Ojiu0lX4T1ZM',
#   'artist_name': 'DJ GL3CHEKY',
#   'external_url': 'https://api.spotify.com/v1/artists/1dX1zejt24Ojiu0lX4T1ZM'},
#  {'artist_id': '6OwbqUSj4XbZdjexPsKkdH',
#   'artist_name': 'PXLWYSE',
#   'external_url': 'https://api.spotify.com/v1/artists/6OwbqUSj4XbZdjexPsKkdH'},
#  {'artist_id': '0oGN0s7dqyWbR41yMsNs0R',
#   'artist_name': 'princce',
#   'external_url': 'https://api.spotify.com/v1/artists/0oGN0s7dqyWbR41yMsNs0R'},
#  {'artist_id': '2YXKTfoEjKVzCNI0J6rHbQ',
#   'artist_name': 'FR3ST',
#   'external_url': 'https://api.spotify.com/v1/artists/2YXKTfoEjKVzCNI0J6rHbQ'},
#  {'artist_id': '3qycxIGAHj1KyoAQ6PGCO6',
#   'artist_name': 'Seek',
#   'external_url': 'https://api.spotify.com/v1/artists/3qycxIGAHj1KyoAQ6PGCO6'},
#  {'artist_id': '33rnQWadiG2aauIwIxPxfB',
#   'artist_name': 'ZWE1HVNDXR',
#   'external_url': 'https://api.spotify.com/v1/artists/33rnQWadiG2aauIwIxPxfB'},
#  {'artist_id': '2APh66XEiqOiDt3bKhBWmn',
#   'artist_name': 'NONTHENSE',
#   'external_url': 'https://api.spotify.com/v1/artists/2APh66XEiqOiDt3bKhBWmn'},
#  {'artist_id': '7dUNKhz7HdxExteqcREGLi',
#   'artist_name': 'Mc Denny',
#   'external_url': 'https://api.spotify.com/v1/artists/7dUNKhz7HdxExteqcREGLi'},
#  {'artist_id': '1nccv1GNVkBdvsYi2FB5FB',
#   'artist_name': 'NUEKI',
#   'external_url': 'https://api.spotify.com/v1/artists/1nccv1GNVkBdvsYi2FB5FB'},
#  {'artist_id': '23P2mSsBpPkfR9fTrOc1a4',
#   'artist_name': 'TOLCHONOV',
#   'external_url': 'https://api.spotify.com/v1/artists/23P2mSsBpPkfR9fTrOc1a4'},
#  {'artist_id': '3wAFY8OyUmqiaPnGbfBSqD',
#   'artist_name': 'DJ NK3',
#   'external_url': 'https://api.spotify.com/v1/artists/3wAFY8OyUmqiaPnGbfBSqD'},
#  {'artist_id': '0sf2x76J3BWkY9mIgFX2Lz',
#   'artist_name': 'THEUZ ZL',
#   'external_url': 'https://api.spotify.com/v1/artists/0sf2x76J3BWkY9mIgFX2Lz'},
#  {'artist_id': '6U0dJxYVB41L8WDZ02Nwuk',
#   'artist_name': 'Dj Samir',
#   'external_url': 'https://api.spotify.com/v1/artists/6U0dJxYVB41L8WDZ02Nwuk'},
#  {'artist_id': '0ngIeXf9eyYCjC1Nen0ux8',
#   'artist_name': 'Rodricci',
#   'external_url': 'https://api.spotify.com/v1/artists/0ngIeXf9eyYCjC1Nen0ux8'},
#  {'artist_id': '3TgsOVvQlRt3sBrIhQ7U9k',
#   'artist_name': 'Launch13',
#   'external_url': 'https://api.spotify.com/v1/artists/3TgsOVvQlRt3sBrIhQ7U9k'},
#  {'artist_id': '7GlC3B9nm2Xcg2Wtw6Av7h',
#   'artist_name': 'Deusas do Funk',
#   'external_url': 'https://api.spotify.com/v1/artists/7GlC3B9nm2Xcg2Wtw6Av7h'},
#  {'artist_id': '1yvmxpLuFjOlHiplr01Hon',
#   'artist_name': 'RELYCT',
#   'external_url': 'https://api.spotify.com/v1/artists/1yvmxpLuFjOlHiplr01Hon'},
#  {'artist_id': '598ZvY8cFQtXgFPBSUm28x',
#   'artist_name': 'ARKEA',
#   'external_url': 'https://api.spotify.com/v1/artists/598ZvY8cFQtXgFPBSUm28x'},
#  {'artist_id': '62D4KEvQMmmK88mTkkWx6Q',
#   'artist_name': 'RD12',
#   'external_url': 'https://api.spotify.com/v1/artists/62D4KEvQMmmK88mTkkWx6Q'},
#  {'artist_id': '2YXKTfoEjKVzCNI0J6rHbQ',
#   'artist_name': 'FR3ST',
#   'external_url': 'https://api.spotify.com/v1/artists/2YXKTfoEjKVzCNI0J6rHbQ'},
#  {'artist_id': '1um8FQQ62RO4ecSx5g3A2E',
#   'artist_name': 'DJ MILLYANN',
#   'external_url': 'https://api.spotify.com/v1/artists/1um8FQQ62RO4ecSx5g3A2E'},
#  {'artist_id': '3uG4rH6Nn0tEvNorkxEs1f',
#   'artist_name': 'VYRUS',
#   'external_url': 'https://api.spotify.com/v1/artists/3uG4rH6Nn0tEvNorkxEs1f'},
#  {'artist_id': '6s4LSwgbzTAfnN6OUfegJB',
#   'artist_name': 'Sayfalse',
#   'external_url': 'https://api.spotify.com/v1/artists/6s4LSwgbzTAfnN6OUfegJB'},
#  {'artist_id': '1iKfUld50BOVBIgHy3GlGt',
#   'artist_name': 'DJ CEREJASS',
#   'external_url': 'https://api.spotify.com/v1/artists/1iKfUld50BOVBIgHy3GlGt'},
#  {'artist_id': '6HwL7jLVz0vywuLyHq3ozr',
#   'artist_name': 'ßino',
#   'external_url': 'https://api.spotify.com/v1/artists/6HwL7jLVz0vywuLyHq3ozr'},
#  {'artist_id': '700c9Qz2z6HZKTumeliKAw',
#   'artist_name': 'LONOWN',
#   'external_url': 'https://api.spotify.com/v1/artists/700c9Qz2z6HZKTumeliKAw'},
#  {'artist_id': '5dDNNq04RjKXFOADdHd6VX',
#   'artist_name': 'Scythermane',
#   'external_url': 'https://api.spotify.com/v1/artists/5dDNNq04RjKXFOADdHd6VX'},
#  {'artist_id': '1viY0nAiEbhiEVJTu2eKDi',
#   'artist_name': 'luc wall',
#   'external_url': 'https://api.spotify.com/v1/artists/1viY0nAiEbhiEVJTu2eKDi'},
#  {'artist_id': '4xWa4k84QliHnu6XzdJeSN',
#   'artist_name': 'Lurk',
#   'external_url': 'https://api.spotify.com/v1/artists/4xWa4k84QliHnu6XzdJeSN'},
#  {'artist_id': '19P1EvDdYzg1ICEyiAEk4m',
#   'artist_name': 'DJ BRYAN 7',
#   'external_url': 'https://api.spotify.com/v1/artists/19P1EvDdYzg1ICEyiAEk4m'},
#  {'artist_id': '4ziGmZKhRvzoP0De6vcXGt',
#   'artist_name': 'DJIEGO',
#   'external_url': 'https://api.spotify.com/v1/artists/4ziGmZKhRvzoP0De6vcXGt'},
#  {'artist_id': '12PDaXrPNMYQsQLnSnDaSS',
#   'artist_name': 'Maxximo Dj',
#   'external_url': 'https://api.spotify.com/v1/artists/12PDaXrPNMYQsQLnSnDaSS'},
#  {'artist_id': '1Z7oSc1PMSULPIoKwUlyb4',
#   'artist_name': 'Mc M4',
#   'external_url': 'https://api.spotify.com/v1/artists/1Z7oSc1PMSULPIoKwUlyb4'},
#  {'artist_id': '62D4KEvQMmmK88mTkkWx6Q',
#   'artist_name': 'RD12',
#   'external_url': 'https://api.spotify.com/v1/artists/62D4KEvQMmmK88mTkkWx6Q'},
#  {'artist_id': '6s4LSwgbzTAfnN6OUfegJB',
#   'artist_name': 'Sayfalse',
#   'external_url': 'https://api.spotify.com/v1/artists/6s4LSwgbzTAfnN6OUfegJB'},
#  {'artist_id': '4nl0CCx6PpEOOr2Z2ThPdp',
#   'artist_name': 'xxanteria',
#   'external_url': 'https://api.spotify.com/v1/artists/4nl0CCx6PpEOOr2Z2ThPdp'},
#  {'artist_id': '3Xd2WSaNywx5gn1pgRPFjF',
#   'artist_name': 'Eternxlkz',
#   'external_url': 'https://api.spotify.com/v1/artists/3Xd2WSaNywx5gn1pgRPFjF'},
#  {'artist_id': '3eTy7yvRHnpPKY4hNCfYYX',
#   'artist_name': 'SXID',
#   'external_url': 'https://api.spotify.com/v1/artists/3eTy7yvRHnpPKY4hNCfYYX'},
#  {'artist_id': '6R26kGib2ubbZJMh7kKVGV',
#   'artist_name': 'Bibi Babydoll',
#   'external_url': 'https://api.spotify.com/v1/artists/6R26kGib2ubbZJMh7kKVGV'},
#  {'artist_id': '6BWtcMF39LT5Db5FT54YYG',
#   'artist_name': 'NCTS',
#   'external_url': 'https://api.spotify.com/v1/artists/6BWtcMF39LT5Db5FT54YYG'},
#  {'artist_id': '4f0duKhSmQubrgvVjUAKvh',
#   'artist_name': 'NXVAMANE',
#   'external_url': 'https://api.spotify.com/v1/artists/4f0duKhSmQubrgvVjUAKvh'},
#  {'artist_id': '5tIkxADHN80ca0K6HCpWIt',
#   'artist_name': 'ZXKAI',
#   'external_url': 'https://api.spotify.com/v1/artists/5tIkxADHN80ca0K6HCpWIt'},
#  {'artist_id': '2DMQ1LeygTDGeyErwBwaeG',
#   'artist_name': 'Mc Talibã',
#   'external_url': 'https://api.spotify.com/v1/artists/2DMQ1LeygTDGeyErwBwaeG'},
#  {'artist_id': '6rzNFUmaEVnYb8kzh9tBTt',
#   'artist_name': 'CURSEDEVIL',
#   'external_url': 'https://api.spotify.com/v1/artists/6rzNFUmaEVnYb8kzh9tBTt'},
#  {'artist_id': '3QMpCp3GHiHXgnX1LldXWe',
#   'artist_name': 'DJ FKU',
#   'external_url': 'https://api.spotify.com/v1/artists/3QMpCp3GHiHXgnX1LldXWe'},
#  {'artist_id': '3voCipmmrW5uF4EMA6aSbj',
#   'artist_name': 'Skorde',
#   'external_url': 'https://api.spotify.com/v1/artists/3voCipmmrW5uF4EMA6aSbj'},
#  {'artist_id': '3rt96VXGtEgD4uSOJ6B69H',
#   'artist_name': 'TRASHXRL',
#   'external_url': 'https://api.spotify.com/v1/artists/3rt96VXGtEgD4uSOJ6B69H'},
#  {'artist_id': '3l4fsEzoeabsET7ddv0lZW',
#   'artist_name': 'Mc Delux',
#   'external_url': 'https://api.spotify.com/v1/artists/3l4fsEzoeabsET7ddv0lZW'},
#  {'artist_id': '5IpS1TN1Crp8Ym4zjiIrtK',
#   'artist_name': 'LXNGVX',
#   'external_url': 'https://api.spotify.com/v1/artists/5IpS1TN1Crp8Ym4zjiIrtK'},
#  {'artist_id': '6kLsCQ1gKvJmjmC8XbfqFE',
#   'artist_name': 'VISXGE',
#   'external_url': 'https://api.spotify.com/v1/artists/6kLsCQ1gKvJmjmC8XbfqFE'},
#  {'artist_id': '5AviPhK4XqgGjtTa0m9aQc',
#   'artist_name': 'NAOMI',
#   'external_url': 'https://api.spotify.com/v1/artists/5AviPhK4XqgGjtTa0m9aQc'},
#  {'artist_id': '3rt96VXGtEgD4uSOJ6B69H',
#   'artist_name': 'TRASHXRL',
#   'external_url': 'https://api.spotify.com/v1/artists/3rt96VXGtEgD4uSOJ6B69H'},
#  {'artist_id': '0ivrHNM8urVaCkgRX8rtKH',
#   'artist_name': 'Mc Menor Do Alvorada',
#   'external_url': 'https://api.spotify.com/v1/artists/0ivrHNM8urVaCkgRX8rtKH'},
#  {'artist_id': '65FHTCI8EmW94W0TdWb8ja',
#   'artist_name': 'Slowboy',
#   'external_url': 'https://api.spotify.com/v1/artists/65FHTCI8EmW94W0TdWb8ja'},
#  {'artist_id': '1nccv1GNVkBdvsYi2FB5FB',
#   'artist_name': 'NUEKI',
#   'external_url': 'https://api.spotify.com/v1/artists/1nccv1GNVkBdvsYi2FB5FB'},
#  {'artist_id': '6QwlKB1hO357wh5oNuuInl',
#   'artist_name': 'Crazy Mano',
#   'external_url': 'https://api.spotify.com/v1/artists/6QwlKB1hO357wh5oNuuInl'},
#  {'artist_id': '23P2mSsBpPkfR9fTrOc1a4',
#   'artist_name': 'TOLCHONOV',
#   'external_url': 'https://api.spotify.com/v1/artists/23P2mSsBpPkfR9fTrOc1a4'},
#  {'artist_id': '21zPGluD0MD68ctSgkuMXi',
#   'artist_name': 'DJ Ikeraus',
#   'external_url': 'https://api.spotify.com/v1/artists/21zPGluD0MD68ctSgkuMXi'},
#  {'artist_id': '5lfW7OqzTLDhvIcHFpxFDB',
#   'artist_name': 'MC FERNANDINHO FN',
#   'external_url': 'https://api.spotify.com/v1/artists/5lfW7OqzTLDhvIcHFpxFDB'},
#  {'artist_id': '6ZhleMHIGIpjkBHrQDl4G7',
#   'artist_name': 'DYGO',
#   'external_url': 'https://api.spotify.com/v1/artists/6ZhleMHIGIpjkBHrQDl4G7'},
#  {'artist_id': '1KoTNs0Ev2KGs7AF5lWlx3',
#   'artist_name': 'Mxng0',
#   'external_url': 'https://api.spotify.com/v1/artists/1KoTNs0Ev2KGs7AF5lWlx3'},
#  {'artist_id': '5WqZHtRzOmKc1hWYfNoo8n',
#   'artist_name': 'TOKYOPHILE',
#   'external_url': 'https://api.spotify.com/v1/artists/5WqZHtRzOmKc1hWYfNoo8n'},
#  {'artist_id': '07MaeHw0cyfmgQ9D9I61UT',
#   'artist_name': 'DJ JEEAN 011',
#   'external_url': 'https://api.spotify.com/v1/artists/07MaeHw0cyfmgQ9D9I61UT'},
#  {'artist_id': '7vfisrjZ6AMRo5vNVLP3qQ',
#   'artist_name': 'MC BM OFICIAL',
#   'external_url': 'https://api.spotify.com/v1/artists/7vfisrjZ6AMRo5vNVLP3qQ'},
#  {'artist_id': '3JFJJKilvJeLfWFA6ENhRS',
#   'artist_name': 'Mc Oliver',
#   'external_url': 'https://api.spotify.com/v1/artists/3JFJJKilvJeLfWFA6ENhRS'},
#  {'artist_id': '5tDcNu62DRxJ4glbImNOy2',
#   'artist_name': 'MC ZKW',
#   'external_url': 'https://api.spotify.com/v1/artists/5tDcNu62DRxJ4glbImNOy2'},
#  {'artist_id': '0LwSj7oJtIyooMGm0PlCbj',
#   'artist_name': 'DJ RD DA DZ7',
#   'external_url': 'https://api.spotify.com/v1/artists/0LwSj7oJtIyooMGm0PlCbj'},
#  {'artist_id': '3uG4rH6Nn0tEvNorkxEs1f',
#   'artist_name': 'VYRUS',
#   'external_url': 'https://api.spotify.com/v1/artists/3uG4rH6Nn0tEvNorkxEs1f'},
#  {'artist_id': '0exQbKNFd9pLmdIGycwmlf',
#   'artist_name': 'h6itam',
#   'external_url': 'https://api.spotify.com/v1/artists/0exQbKNFd9pLmdIGycwmlf'},
#  {'artist_id': '4o5PswOvXGSq0y5BqZTR9n',
#   'artist_name': 'STRAWANGLE',
#   'external_url': 'https://api.spotify.com/v1/artists/4o5PswOvXGSq0y5BqZTR9n'},
#  {'artist_id': '2JrpgVMFW3Hpe1CwLaAORl',
#   'artist_name': 'MC RP VK',
#   'external_url': 'https://api.spotify.com/v1/artists/2JrpgVMFW3Hpe1CwLaAORl'},
#  {'artist_id': '2ge1WtiBqengw0nAnq94Zo',
#   'artist_name': 'MC Da 12',
#   'external_url': 'https://api.spotify.com/v1/artists/2ge1WtiBqengw0nAnq94Zo'},
#  {'artist_id': '6JjQbtAO09K7qBEW2pdX5s',
#   'artist_name': 'isq',
#   'external_url': 'https://api.spotify.com/v1/artists/6JjQbtAO09K7qBEW2pdX5s'},
#  {'artist_id': '3Ng2KitKkpjyym1V03mV00',
#   'artist_name': 'Astora',
#   'external_url': 'https://api.spotify.com/v1/artists/3Ng2KitKkpjyym1V03mV00'},
#  {'artist_id': '7lAaAGxYxk2GH8cMbTEwAL',
#   'artist_name': 'NXGHT!',
#   'external_url': 'https://api.spotify.com/v1/artists/7lAaAGxYxk2GH8cMbTEwAL'},
#  {'artist_id': '3wQNcarvRuzhz2Fg1pVDxZ',
#   'artist_name': 'DJ ANXVAR',
#   'external_url': 'https://api.spotify.com/v1/artists/3wQNcarvRuzhz2Fg1pVDxZ'},
#  {'artist_id': '1HJglK87YzctjxETSJqh64',
#   'artist_name': 'DJ ZAP',
#   'external_url': 'https://api.spotify.com/v1/artists/1HJglK87YzctjxETSJqh64'},
#  {'artist_id': '4H61c3XQu4PswXGtB0MJ6N',
#   'artist_name': 'Hexora',
#   'external_url': 'https://api.spotify.com/v1/artists/4H61c3XQu4PswXGtB0MJ6N'},
#  {'artist_id': '6WCBS0WuEBBtdV7TZMtCnh',
#   'artist_name': 'Artox',
#   'external_url': 'https://api.spotify.com/v1/artists/6WCBS0WuEBBtdV7TZMtCnh'},
#  {'artist_id': '4epIlGy9RGEMdrfSXS2HEc',
#   'artist_name': 'Alert',
#   'external_url': 'https://api.spotify.com/v1/artists/4epIlGy9RGEMdrfSXS2HEc'},
#  {'artist_id': '5Vd9shhZpzTYaaZ6KQNnjU',
#   'artist_name': 'GLXXMSTRIDER',
#   'external_url': 'https://api.spotify.com/v1/artists/5Vd9shhZpzTYaaZ6KQNnjU'},
#  {'artist_id': '3Xd2WSaNywx5gn1pgRPFjF',
#   'artist_name': 'Eternxlkz',
#   'external_url': 'https://api.spotify.com/v1/artists/3Xd2WSaNywx5gn1pgRPFjF'},
#  {'artist_id': '3c4ngCW3y8USmyrjRdB1mG',
#   'artist_name': 'ARXMANE',
#   'external_url': 'https://api.spotify.com/v1/artists/3c4ngCW3y8USmyrjRdB1mG'},
#  {'artist_id': '5IpS1TN1Crp8Ym4zjiIrtK',
#   'artist_name': 'LXNGVX',
#   'external_url': 'https://api.spotify.com/v1/artists/5IpS1TN1Crp8Ym4zjiIrtK'},
#  {'artist_id': '6HJiLhKqnOh32p3LSNWsR3',
#   'artist_name': 'Dj Gabriel do Borel',
#   'external_url': 'https://api.spotify.com/v1/artists/6HJiLhKqnOh32p3LSNWsR3'},
#  {'artist_id': '5WqZHtRzOmKc1hWYfNoo8n',
#   'artist_name': 'TOKYOPHILE',
#   'external_url': 'https://api.spotify.com/v1/artists/5WqZHtRzOmKc1hWYfNoo8n'},
#  {'artist_id': '648ZoUpTM6iIMTCgo3lLCE',
#   'artist_name': 'DJ Paulinho Mondi Da Baixa Baviera',
#   'external_url': 'https://api.spotify.com/v1/artists/648ZoUpTM6iIMTCgo3lLCE'},
#  {'artist_id': '0sjGfRBmq6lKmUNgt8Ptic',
#   'artist_name': 'Mc Vitorioso',
#   'external_url': 'https://api.spotify.com/v1/artists/0sjGfRBmq6lKmUNgt8Ptic'},
#  {'artist_id': '60vF1fLR6yzLxCQUlnAYYj',
#   'artist_name': '$werve',
#   'external_url': 'https://api.spotify.com/v1/artists/60vF1fLR6yzLxCQUlnAYYj'},
#  {'artist_id': '5UKXrvmyouEgmvon7DwwzA',
#   'artist_name': 'FXRCE',
#   'external_url': 'https://api.spotify.com/v1/artists/5UKXrvmyouEgmvon7DwwzA'},
#  {'artist_id': '7dUNKhz7HdxExteqcREGLi',
#   'artist_name': 'Mc Denny',
#   'external_url': 'https://api.spotify.com/v1/artists/7dUNKhz7HdxExteqcREGLi'},
#  {'artist_id': '1yTrrABG9Vr2Y9lbHupN3f',
#   'artist_name': 'DJ Vilão DS',
#   'external_url': 'https://api.spotify.com/v1/artists/1yTrrABG9Vr2Y9lbHupN3f'},
#  {'artist_id': '4kEtpjbEnSh4WNeLF1IeG7',
#   'artist_name': 'MC Zudo Boladão',
#   'external_url': 'https://api.spotify.com/v1/artists/4kEtpjbEnSh4WNeLF1IeG7'},
#  {'artist_id': '3LfT6BvsnMomxucwVAXGiF',
#   'artist_name': 'DJ Magrin Da DZ7',
#   'external_url': 'https://api.spotify.com/v1/artists/3LfT6BvsnMomxucwVAXGiF'},
#  {'artist_id': '2dZI1nDPMCgcymfUeLIObc',
#   'artist_name': 'MC PH77',
#   'external_url': 'https://api.spotify.com/v1/artists/2dZI1nDPMCgcymfUeLIObc'},
#  {'artist_id': '19P1EvDdYzg1ICEyiAEk4m',
#   'artist_name': 'DJ BRYAN 7',
#   'external_url': 'https://api.spotify.com/v1/artists/19P1EvDdYzg1ICEyiAEk4m'},
#  {'artist_id': '4ziGmZKhRvzoP0De6vcXGt',
#   'artist_name': 'DJIEGO',
#   'external_url': 'https://api.spotify.com/v1/artists/4ziGmZKhRvzoP0De6vcXGt'},
#  {'artist_id': '12PDaXrPNMYQsQLnSnDaSS',
#   'artist_name': 'Maxximo Dj',
#   'external_url': 'https://api.spotify.com/v1/artists/12PDaXrPNMYQsQLnSnDaSS'},
#  {'artist_id': '1Z7oSc1PMSULPIoKwUlyb4',
#   'artist_name': 'Mc M4',
#   'external_url': 'https://api.spotify.com/v1/artists/1Z7oSc1PMSULPIoKwUlyb4'},
#  {'artist_id': '4RsEAdLhbUy7j3zHWauPwF',
#   'artist_name': 'BLESSED MANE',
#   'external_url': 'https://api.spotify.com/v1/artists/4RsEAdLhbUy7j3zHWauPwF'},
#  {'artist_id': '5joODcLQTClX0o3q13SOfU',
#   'artist_name': 'RXPOSO99',
#   'external_url': 'https://api.spotify.com/v1/artists/5joODcLQTClX0o3q13SOfU'},
#  {'artist_id': '3l4fsEzoeabsET7ddv0lZW',
#   'artist_name': 'Mc Delux',
#   'external_url': 'https://api.spotify.com/v1/artists/3l4fsEzoeabsET7ddv0lZW'},
#  {'artist_id': '5IpS1TN1Crp8Ym4zjiIrtK',
#   'artist_name': 'LXNGVX',
#   'external_url': 'https://api.spotify.com/v1/artists/5IpS1TN1Crp8Ym4zjiIrtK'},
#  {'artist_id': '0f1IECbrVV952unZkzrsg2',
#   'artist_name': 'Mc Gw',
#   'external_url': 'https://api.spotify.com/v1/artists/0f1IECbrVV952unZkzrsg2'},
#  {'artist_id': '1iKfUld50BOVBIgHy3GlGt',
#   'artist_name': 'DJ CEREJASS',
#   'external_url': 'https://api.spotify.com/v1/artists/1iKfUld50BOVBIgHy3GlGt'},
#  {'artist_id': '6s4LSwgbzTAfnN6OUfegJB',
#   'artist_name': 'Sayfalse',
#   'external_url': 'https://api.spotify.com/v1/artists/6s4LSwgbzTAfnN6OUfegJB'},
#  {'artist_id': '2DtIt7mMzdaEEFVUbSmnoU',
#   'artist_name': 'LDRR',
#   'external_url': 'https://api.spotify.com/v1/artists/2DtIt7mMzdaEEFVUbSmnoU'},
#  {'artist_id': '09cKncAQn28NqTUORLMwSR',
#   'artist_name': 'Ariis',
#   'external_url': 'https://api.spotify.com/v1/artists/09cKncAQn28NqTUORLMwSR'},
#  {'artist_id': '0exQbKNFd9pLmdIGycwmlf',
#   'artist_name': 'h6itam',
#   'external_url': 'https://api.spotify.com/v1/artists/0exQbKNFd9pLmdIGycwmlf'},
#  {'artist_id': '4cM6xcafBAbS9bOa8kAjRj',
#   'artist_name': 'ICEDMANE',
#   'external_url': 'https://api.spotify.com/v1/artists/4cM6xcafBAbS9bOa8kAjRj'},
#  {'artist_id': '1pFLuMBwabtFITLNJlEZ9z',
#   'artist_name': 'DYSMANE',
#   'external_url': 'https://api.spotify.com/v1/artists/1pFLuMBwabtFITLNJlEZ9z'},
#  {'artist_id': '1cCYuIofJkQf9YN1FZo5A4',
#   'artist_name': 'DJ OLIVEIRA ORIGINAL',
#   'external_url': 'https://api.spotify.com/v1/artists/1cCYuIofJkQf9YN1FZo5A4'},
#  {'artist_id': '44AXaX2aJKSQhMxVTtNb0s',
#   'artist_name': 'Mc Koruja',
#   'external_url': 'https://api.spotify.com/v1/artists/44AXaX2aJKSQhMxVTtNb0s'},
#  {'artist_id': '3uA4unR7LBOcqjpbOeCs0Y',
#   'artist_name': '-Prey',
#   'external_url': 'https://api.spotify.com/v1/artists/3uA4unR7LBOcqjpbOeCs0Y'},
#  {'artist_id': '6ESoeEazu57neU7UM6KRuC',
#   'artist_name': 'UdieNnx',
#   'external_url': 'https://api.spotify.com/v1/artists/6ESoeEazu57neU7UM6KRuC'},
#  {'artist_id': '0f1IECbrVV952unZkzrsg2',
#   'artist_name': 'Mc Gw',
#   'external_url': 'https://api.spotify.com/v1/artists/0f1IECbrVV952unZkzrsg2'},
#  {'artist_id': '1TTHC3GlNDaE5eVoC3BVxm',
#   'artist_name': 'Lumi Athena',
#   'external_url': 'https://api.spotify.com/v1/artists/1TTHC3GlNDaE5eVoC3BVxm'},
#  {'artist_id': '3yn6fs9MkW1i4V3S2G8Dxs',
#   'artist_name': 'vtze archive',
#   'external_url': 'https://api.spotify.com/v1/artists/3yn6fs9MkW1i4V3S2G8Dxs'},
#  {'artist_id': '2RqjTHL40djgpNGG2LS9O0',
#   'artist_name': 'Mc Ster',
#   'external_url': 'https://api.spotify.com/v1/artists/2RqjTHL40djgpNGG2LS9O0'},
#  {'artist_id': '3QMpCp3GHiHXgnX1LldXWe',
#   'artist_name': 'DJ FKU',
#   'external_url': 'https://api.spotify.com/v1/artists/3QMpCp3GHiHXgnX1LldXWe'},
#  {'artist_id': '3wQNcarvRuzhz2Fg1pVDxZ',
#   'artist_name': 'DJ ANXVAR',
#   'external_url': 'https://api.spotify.com/v1/artists/3wQNcarvRuzhz2Fg1pVDxZ'},
#  {'artist_id': '1nzIoHG5B7klgAPdwjqRDj',
#   'artist_name': 'MC LONE',
#   'external_url': 'https://api.spotify.com/v1/artists/1nzIoHG5B7klgAPdwjqRDj'},
#  {'artist_id': '6R26kGib2ubbZJMh7kKVGV',
#   'artist_name': 'Bibi Babydoll',
#   'external_url': 'https://api.spotify.com/v1/artists/6R26kGib2ubbZJMh7kKVGV'},
#  {'artist_id': '3QMpCp3GHiHXgnX1LldXWe',
#   'artist_name': 'DJ FKU',
#   'external_url': 'https://api.spotify.com/v1/artists/3QMpCp3GHiHXgnX1LldXWe'},
#  {'artist_id': '1M02J1PLobtQYok93DEvVa',
#   'artist_name': 'slxughter',
#   'external_url': 'https://api.spotify.com/v1/artists/1M02J1PLobtQYok93DEvVa'},
#  {'artist_id': '0f1IECbrVV952unZkzrsg2',
#   'artist_name': 'Mc Gw',
#   'external_url': 'https://api.spotify.com/v1/artists/0f1IECbrVV952unZkzrsg2'},
#  {'artist_id': '4C5EDmZfgkkSwUVFSvuUNP',
#   'artist_name': 'Anar',
#   'external_url': 'https://api.spotify.com/v1/artists/4C5EDmZfgkkSwUVFSvuUNP'},
#  {'artist_id': '4DWPOsGWbW7sBHb1UuBvWs',
#   'artist_name': 'Polaris',
#   'external_url': 'https://api.spotify.com/v1/artists/4DWPOsGWbW7sBHb1UuBvWs'},
#  {'artist_id': '5IpS1TN1Crp8Ym4zjiIrtK',
#   'artist_name': 'LXNGVX',
#   'external_url': 'https://api.spotify.com/v1/artists/5IpS1TN1Crp8Ym4zjiIrtK'},
#  {'artist_id': '3l4fsEzoeabsET7ddv0lZW',
#   'artist_name': 'Mc Delux',
#   'external_url': 'https://api.spotify.com/v1/artists/3l4fsEzoeabsET7ddv0lZW'},
#  {'artist_id': '6wWEEpCzvBH6Z5EVZ86wJl',
#   'artist_name': 'Ichiss',
#   'external_url': 'https://api.spotify.com/v1/artists/6wWEEpCzvBH6Z5EVZ86wJl'},
#  {'artist_id': '3rX0drWPVa50yFG3HqzX0T',
#   'artist_name': 'DJ MAXZZ',
#   'external_url': 'https://api.spotify.com/v1/artists/3rX0drWPVa50yFG3HqzX0T'},
#  {'artist_id': '68J0b3Hj9aurxWUiy9FUMu',
#   'artist_name': 'DJ JL3 DA ZN',
#   'external_url': 'https://api.spotify.com/v1/artists/68J0b3Hj9aurxWUiy9FUMu'},
#  {'artist_id': '33wh7J44m0CrsAFj2LuRk2',
#   'artist_name': 'DJ CD 011',
#   'external_url': 'https://api.spotify.com/v1/artists/33wh7J44m0CrsAFj2LuRk2'},
#  {'artist_id': '4C5EDmZfgkkSwUVFSvuUNP',
#   'artist_name': 'Anar',
#   'external_url': 'https://api.spotify.com/v1/artists/4C5EDmZfgkkSwUVFSvuUNP'},
#  {'artist_id': '4DWPOsGWbW7sBHb1UuBvWs',
#   'artist_name': 'Polaris',
#   'external_url': 'https://api.spotify.com/v1/artists/4DWPOsGWbW7sBHb1UuBvWs'},
#  {'artist_id': '1PvcWjADPMezv8CTyJO9Uk',
#   'artist_name': 'Vermillion',
#   'external_url': 'https://api.spotify.com/v1/artists/1PvcWjADPMezv8CTyJO9Uk'},
#  {'artist_id': '4cM6xcafBAbS9bOa8kAjRj',
#   'artist_name': 'ICEDMANE',
#   'external_url': 'https://api.spotify.com/v1/artists/4cM6xcafBAbS9bOa8kAjRj'},
#  {'artist_id': '1pFLuMBwabtFITLNJlEZ9z',
#   'artist_name': 'DYSMANE',
#   'external_url': 'https://api.spotify.com/v1/artists/1pFLuMBwabtFITLNJlEZ9z'},
#  {'artist_id': '3AbeBDqk7IsG1JZEWVVcpY',
#   'artist_name': 'Mc Dido',
#   'external_url': 'https://api.spotify.com/v1/artists/3AbeBDqk7IsG1JZEWVVcpY'},
#  {'artist_id': '5Z56BMrvQB2rBAa5kffTPD',
#   'artist_name': 'HISTED',
#   'external_url': 'https://api.spotify.com/v1/artists/5Z56BMrvQB2rBAa5kffTPD'},
#  {'artist_id': '4Rd0aHKGS9BdLYSXVvFjv5',
#   'artist_name': 'TXVSTERPLAYA',
#   'external_url': 'https://api.spotify.com/v1/artists/4Rd0aHKGS9BdLYSXVvFjv5'},
#  {'artist_id': '2sQHo73pQF1OTq3lDuQhlO',
#   'artist_name': 'Mc Pogba',
#   'external_url': 'https://api.spotify.com/v1/artists/2sQHo73pQF1OTq3lDuQhlO'},
#  {'artist_id': '0rb23mC6LLZ3o15qcdSzjx',
#   'artist_name': 'DJ Guih Da ZO',
#   'external_url': 'https://api.spotify.com/v1/artists/0rb23mC6LLZ3o15qcdSzjx'},
#  {'artist_id': '24YUNOEuu3kf4OOtC8cQE5',
#   'artist_name': '6YNTHMANE',
#   'external_url': 'https://api.spotify.com/v1/artists/24YUNOEuu3kf4OOtC8cQE5'},
#  {'artist_id': '54HaZmktN1cmdL8Ygdrmzz',
#   'artist_name': 'RXDXVIL',
#   'external_url': 'https://api.spotify.com/v1/artists/54HaZmktN1cmdL8Ygdrmzz'},
#  {'artist_id': '32Pxa55IN0QAmFtzWcT2w9',
#   'artist_name': 'qaraqshy',
#   'external_url': 'https://api.spotify.com/v1/artists/32Pxa55IN0QAmFtzWcT2w9'},
#  {'artist_id': '1nzIoHG5B7klgAPdwjqRDj',
#   'artist_name': 'MC LONE',
#   'external_url': 'https://api.spotify.com/v1/artists/1nzIoHG5B7klgAPdwjqRDj'},
#  {'artist_id': '56zHTpLLVZ6otn4eInVwJf',
#   'artist_name': 'Lyu',
#   'external_url': 'https://api.spotify.com/v1/artists/56zHTpLLVZ6otn4eInVwJf'},
#  {'artist_id': '1YVpgYKow2RgW5ZDLmApGf',
#   'artist_name': 'ITALO SENA',
#   'external_url': 'https://api.spotify.com/v1/artists/1YVpgYKow2RgW5ZDLmApGf'},
#  {'artist_id': '6tQDQivRhULyEMBCneS7f9',
#   'artist_name': 'DJ PBeats',
#   'external_url': 'https://api.spotify.com/v1/artists/6tQDQivRhULyEMBCneS7f9'},
#  {'artist_id': '3uG4rH6Nn0tEvNorkxEs1f',
#   'artist_name': 'VYRUS',
#   'external_url': 'https://api.spotify.com/v1/artists/3uG4rH6Nn0tEvNorkxEs1f'},
#  {'artist_id': '4pmKpROq7rAVibM7qR9h6P',
#   'artist_name': 'DJ ZBK',
#   'external_url': 'https://api.spotify.com/v1/artists/4pmKpROq7rAVibM7qR9h6P'},
#  {'artist_id': '62D4KEvQMmmK88mTkkWx6Q',
#   'artist_name': 'RD12',
#   'external_url': 'https://api.spotify.com/v1/artists/62D4KEvQMmmK88mTkkWx6Q'},
#  {'artist_id': '1qaCszXlFNPEnCELYBixa5',
#   'artist_name': 'M4GN',
#   'external_url': 'https://api.spotify.com/v1/artists/1qaCszXlFNPEnCELYBixa5'},
#  {'artist_id': '2ZuUKw4Pfvj7zIKxYY3HAh',
#   'artist_name': 'DJ Oliver Mendes',
#   'external_url': 'https://api.spotify.com/v1/artists/2ZuUKw4Pfvj7zIKxYY3HAh'}]

# %%
song_list = []
for i in data['items']:
    song_id = i['track']['id']
    song_name = i['track']['name']
    song_duration = i['track']['duration_ms']
    song_url = i['track']['external_urls']['spotify']
    song_popularity = i['track']['popularity']
    song_added = i['added_at']
    album_id = i['track']['album']['id']
    artist_id = i['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,'popularity':song_popularity,'song_added':song_added,'album_id':album_id,'artist_id':artist_id}
    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '5EIjpM1B1VsLoKvv2iwd0P',
#   'song_name': 'NUNCA MUDA?',
#   'duration_ms': 81500,
#   'url': 'https://open.spotify.com/track/5EIjpM1B1VsLoKvv2iwd0P',
#   'popularity': 86,
#   'song_added': '2025-03-07T07:49:17Z',
#   'album_id': '6xUYw5goKIoyJQi9C27UBy',
#   'artist_id': '5dDNNq04RjKXFOADdHd6VX'},
#  {'song_id': '1mfvWzF39LwVpAm8g0LhQT',
#   'song_name': 'MONTAGEM TOMADA - Slowed',
#   'duration_ms': 84901,
#   'url': 'https://open.spotify.com/track/1mfvWzF39LwVpAm8g0LhQT',
#   'popularity': 81,
#   'song_added': '2025-04-10T07:43:26Z',
#   'album_id': '5D17Gk0J7jPXLvWMszqijF',
#   'artist_id': '7kk9ucvRJim0NMM89Lml2Y'},
#  {'song_id': '466x7CJlVwiFdNTLvIXwZl',
#   'song_name': 'FUNK UNIVERSO',
#   'duration_ms': 127500,
#   'url': 'https://open.spotify.com/track/466x7CJlVwiFdNTLvIXwZl',
#   'popularity': 78,
#   'song_added': '2025-03-07T07:49:36Z',
#   'album_id': '1kmsUHDC0n611meNgzRkuw',
#   'artist_id': '2vKxv2oKVSEJZ1VmuLUOvY'},
#  {'song_id': '48WnIIBbnttcwUQ77MBoMI',
#   'song_name': 'MONTAGEM LADRAO',
#   'duration_ms': 75240,
#   'url': 'https://open.spotify.com/track/48WnIIBbnttcwUQ77MBoMI',
#   'popularity': 82,
#   'song_added': '2025-04-01T18:18:31Z',
#   'album_id': '3Aw43kkDlLE5ZXwQPGHWgO',
#   'artist_id': '5SCDfg1YoEfI5gFtXqEWah'},
#  {'song_id': '5XwNsUvJxk38263zeXrfXI',
#   'song_name': 'MTG - RITMO ZELDA - Super Slowed',
#   'duration_ms': 107093,
#   'url': 'https://open.spotify.com/track/5XwNsUvJxk38263zeXrfXI',
#   'popularity': 75,
#   'song_added': '2025-03-20T11:10:50Z',
#   'album_id': '62R2H85ZiKLp0lYHPprQWV',
#   'artist_id': '2nGwC9QG6Hpw4fSDgNpn5n'},
#  {'song_id': '43jExF2HeZ6cJIGrWF0ie4',
#   'song_name': 'Funk de Beleza - Slowed',
#   'duration_ms': 145115,
#   'url': 'https://open.spotify.com/track/43jExF2HeZ6cJIGrWF0ie4',
#   'popularity': 86,
#   'song_added': '2025-03-07T07:49:21Z',
#   'album_id': '4s7LxMlh6RxgdMhldfMe8u',
#   'artist_id': '3g0UoyvaTaHUrfpHiRqsD1'},
#  {'song_id': '0cJwt3tpaMOXPAXkaHAp7k',
#   'song_name': 'BOUNCE FUNK - Slowed',
#   'duration_ms': 97368,
#   'url': 'https://open.spotify.com/track/0cJwt3tpaMOXPAXkaHAp7k',
#   'popularity': 75,
#   'song_added': '2025-03-26T23:51:24Z',
#   'album_id': '572YC1K4uc7PjFqb6xaICD',
#   'artist_id': '0pSdNszQKrzI6m9okVVSL5'},
#  {'song_id': '4VL5XwfATZuAVTW471Wpro',
#   'song_name': 'FUNKED UP - SLOWED',
#   'duration_ms': 115348,
#   'url': 'https://open.spotify.com/track/4VL5XwfATZuAVTW471Wpro',
#   'popularity': 78,
#   'song_added': '2025-03-07T08:19:08Z',
#   'album_id': '4FRxgE6LA2UGJ5yz8diaI9',
#   'artist_id': '4nl0CCx6PpEOOr2Z2ThPdp'},
#  {'song_id': '2YZ7CJV3Q1OGh7ZL9PYWcP',
#   'song_name': 'GLORY',
#   'duration_ms': 149522,
#   'url': 'https://open.spotify.com/track/2YZ7CJV3Q1OGh7ZL9PYWcP',
#   'popularity': 83,
#   'song_added': '2025-03-07T07:47:52Z',
#   'album_id': '3tSeUNn7yOQPEex7jwS9Bf',
#   'artist_id': '1Sdc6ySbIvzO0X9vbyHzWm'},
#  {'song_id': '3c1rQB4Q5plN80oyUwixG3',
#   'song_name': 'EMPIRE - Slowed',
#   'duration_ms': 115803,
#   'url': 'https://open.spotify.com/track/3c1rQB4Q5plN80oyUwixG3',
#   'popularity': 69,
#   'song_added': '2025-03-07T07:47:57Z',
#   'album_id': '6YLJD87ZAaFBziGObBIcOW',
#   'artist_id': '1Sdc6ySbIvzO0X9vbyHzWm'},
#  {'song_id': '2TNv2GxMpIO8AyPiD7TLxj',
#   'song_name': 'AURA',
#   'duration_ms': 115906,
#   'url': 'https://open.spotify.com/track/2TNv2GxMpIO8AyPiD7TLxj',
#   'popularity': 80,
#   'song_added': '2025-03-07T07:47:46Z',
#   'album_id': '06a7H7nusNMvM7yL8m3fy1',
#   'artist_id': '1Sdc6ySbIvzO0X9vbyHzWm'},
#  {'song_id': '7IBqHkoP94VrgYKVns4eNz',
#   'song_name': 'FUNK DO BOUNCE (Slowed)',
#   'duration_ms': 107539,
#   'url': 'https://open.spotify.com/track/7IBqHkoP94VrgYKVns4eNz',
#   'popularity': 84,
#   'song_added': '2025-03-07T07:49:29Z',
#   'album_id': '6Zd0Hg3HKVH7xhBPgESQy1',
#   'artist_id': '09cKncAQn28NqTUORLMwSR'},
#  {'song_id': '0ePdvQb4qFBA9Ps1QZwhMu',
#   'song_name': 'hypnotic - super slowed',
#   'duration_ms': 120796,
#   'url': 'https://open.spotify.com/track/0ePdvQb4qFBA9Ps1QZwhMu',
#   'popularity': 79,
#   'song_added': '2025-03-07T07:49:46Z',
#   'album_id': '1dNr9lYDxO0pyG6poLIVWA',
#   'artist_id': '6JjQbtAO09K7qBEW2pdX5s'},
#  {'song_id': '60AVJqYgyAlCckC6Nh2tgO',
#   'song_name': 'X-SLIDE',
#   'duration_ms': 79452,
#   'url': 'https://open.spotify.com/track/60AVJqYgyAlCckC6Nh2tgO',
#   'popularity': 80,
#   'song_added': '2025-03-07T07:51:56Z',
#   'album_id': '1QFKbF3Oot9Ad1NnRCAG32',
#   'artist_id': '2vPnS0IpayC2RVFuQA08R4'},
#  {'song_id': '4aT2W9wchQKAimxVFSRIva',
#   'song_name': 'SPOOKY',
#   'duration_ms': 96923,
#   'url': 'https://open.spotify.com/track/4aT2W9wchQKAimxVFSRIva',
#   'popularity': 82,
#   'song_added': '2025-03-07T07:52:00Z',
#   'album_id': '4QmDrxVGw99LUJOubfPJz9',
#   'artist_id': '5tvPbCrx8LMaL9Zby5e7c2'},
#  {'song_id': '6yIkBXij6NSjmRGRpQupqO',
#   'song_name': 'X-TALI',
#   'duration_ms': 72352,
#   'url': 'https://open.spotify.com/track/6yIkBXij6NSjmRGRpQupqO',
#   'popularity': 75,
#   'song_added': '2025-03-07T07:52:21Z',
#   'album_id': '6dNugoBYWvUDQDtLurImhw',
#   'artist_id': '7qIgmxSjoXEeifSVDh8nIt'},
#  {'song_id': '24WBge8e53iDTeXOtVB02s',
#   'song_name': 'Eu Sento Gabu!',
#   'duration_ms': 83754,
#   'url': 'https://open.spotify.com/track/24WBge8e53iDTeXOtVB02s',
#   'popularity': 77,
#   'song_added': '2025-03-07T07:52:05Z',
#   'album_id': '51F5iHYpECc8dd9Wjqv15o',
#   'artist_id': '6OwbqUSj4XbZdjexPsKkdH'},
#  {'song_id': '2vbl2mqgwZCPqiYjn3MPhS',
#   'song_name': 'EI DO SENSACIO!',
#   'duration_ms': 101089,
#   'url': 'https://open.spotify.com/track/2vbl2mqgwZCPqiYjn3MPhS',
#   'popularity': 71,
#   'song_added': '2025-03-07T07:52:14Z',
#   'album_id': '1qlnjo9SZtK01FqDyjv6nM',
#   'artist_id': '0oGN0s7dqyWbR41yMsNs0R'},
#  {'song_id': '6Seth37t5I69wFbuGFrsiG',
#   'song_name': 'REI DO BRASIL',
#   'duration_ms': 97846,
#   'url': 'https://open.spotify.com/track/6Seth37t5I69wFbuGFrsiG',
#   'popularity': 66,
#   'song_added': '2025-03-07T07:54:42Z',
#   'album_id': '5rDznSixlUXNxJySfWQNb7',
#   'artist_id': '3qycxIGAHj1KyoAQ6PGCO6'},
#  {'song_id': '3cjg55upztjI5bIsBQqSN1',
#   'song_name': 'THOMAS',
#   'duration_ms': 90603,
#   'url': 'https://open.spotify.com/track/3cjg55upztjI5bIsBQqSN1',
#   'popularity': 67,
#   'song_added': '2025-03-07T07:54:51Z',
#   'album_id': '6s28IiIJ7ElbJfTPn03D6Y',
#   'artist_id': '33rnQWadiG2aauIwIxPxfB'},
#  {'song_id': '586x98q1tY2vlDlhN1BwQM',
#   'song_name': 'Mexican Phonk Eki',
#   'duration_ms': 98067,
#   'url': 'https://open.spotify.com/track/586x98q1tY2vlDlhN1BwQM',
#   'popularity': 69,
#   'song_added': '2025-03-07T07:54:56Z',
#   'album_id': '1vQpZhp0nRdlUT4m2cgV4k',
#   'artist_id': '1nccv1GNVkBdvsYi2FB5FB'},
#  {'song_id': '1bGCQoaz734Y5jeZ6GiUZ1',
#   'song_name': 'PLANETA DESCONHECIDO',
#   'duration_ms': 144019,
#   'url': 'https://open.spotify.com/track/1bGCQoaz734Y5jeZ6GiUZ1',
#   'popularity': 68,
#   'song_added': '2025-03-07T07:55:04Z',
#   'album_id': '3I0PQFWT0lGD5zWcGHwbRW',
#   'artist_id': '3wAFY8OyUmqiaPnGbfBSqD'},
#  {'song_id': '0Qw37MnASRbS88i6Ee6nGq',
#   'song_name': 'Louca Encubada',
#   'duration_ms': 119221,
#   'url': 'https://open.spotify.com/track/0Qw37MnASRbS88i6Ee6nGq',
#   'popularity': 70,
#   'song_added': '2025-03-07T07:55:09Z',
#   'album_id': '1XFONq6J523aOBZDsjtCW8',
#   'artist_id': '6U0dJxYVB41L8WDZ02Nwuk'},
#  {'song_id': '7GqWUQv53sNEC7mudubpaq',
#   'song_name': 'A-What',
#   'duration_ms': 98000,
#   'url': 'https://open.spotify.com/track/7GqWUQv53sNEC7mudubpaq',
#   'popularity': 71,
#   'song_added': '2025-03-07T07:57:24Z',
#   'album_id': '0FNQKStah5NuLZu0Npw17w',
#   'artist_id': '1yvmxpLuFjOlHiplr01Hon'},
#  {'song_id': '2f0ICQHa6q8hr5HjeFmDJO',
#   'song_name': 'Se Paciente Funk',
#   'duration_ms': 69360,
#   'url': 'https://open.spotify.com/track/2f0ICQHa6q8hr5HjeFmDJO',
#   'popularity': 71,
#   'song_added': '2025-03-07T07:57:28Z',
#   'album_id': '3Ar02fcnzPDg1xvy05pWff',
#   'artist_id': '62D4KEvQMmmK88mTkkWx6Q'},
#  {'song_id': '5PHdyF0lk5ZWzow4aUSfPL',
#   'song_name': 'EL QUE LA DEBE FUNK - SLOWED',
#   'duration_ms': 108344,
#   'url': 'https://open.spotify.com/track/5PHdyF0lk5ZWzow4aUSfPL',
#   'popularity': 69,
#   'song_added': '2025-03-07T07:57:32Z',
#   'album_id': '2i9lYE2CWNBLmDiXwJ884n',
#   'artist_id': '2YXKTfoEjKVzCNI0J6rHbQ'},
#  {'song_id': '1vJE1HgDMBhzwXTbGiXFVx',
#   'song_name': 'BAD PARENTING FUNK V2',
#   'duration_ms': 78777,
#   'url': 'https://open.spotify.com/track/1vJE1HgDMBhzwXTbGiXFVx',
#   'popularity': 71,
#   'song_added': '2025-03-07T07:57:37Z',
#   'album_id': '6mfljhxeSViWr01HscxHjS',
#   'artist_id': '6s4LSwgbzTAfnN6OUfegJB'},
#  {'song_id': '1EPi3TSB6vGbGQ4IHVpxco',
#   'song_name': 'AVANGARD - Slowed',
#   'duration_ms': 199450,
#   'url': 'https://open.spotify.com/track/1EPi3TSB6vGbGQ4IHVpxco',
#   'popularity': 76,
#   'song_added': '2025-03-07T07:57:42Z',
#   'album_id': '5n9EF7hP2GRMiklzLpPY0E',
#   'artist_id': '700c9Qz2z6HZKTumeliKAw'},
#  {'song_id': '5Vuq8CP31cpEEq5zNJCjUN',
#   'song_name': 'JOGO DE TOLOS',
#   'duration_ms': 70400,
#   'url': 'https://open.spotify.com/track/5Vuq8CP31cpEEq5zNJCjUN',
#   'popularity': 74,
#   'song_added': '2025-03-07T07:59:36Z',
#   'album_id': '3ra1kh1AmwAFm1jg9dwONE',
#   'artist_id': '5dDNNq04RjKXFOADdHd6VX'},
#  {'song_id': '1H5PVxswRh4KpLoW5o78VJ',
#   'song_name': 'O Melhor no Que Faz 3.0 [Slowed]',
#   'duration_ms': 144000,
#   'url': 'https://open.spotify.com/track/1H5PVxswRh4KpLoW5o78VJ',
#   'popularity': 69,
#   'song_added': '2025-03-07T07:59:41Z',
#   'album_id': '1Wr2LyF0JSHHPv9nGXgFTN',
#   'artist_id': '19P1EvDdYzg1ICEyiAEk4m'},
#  {'song_id': '4YvxfQF9QCXykqi2ahREC4',
#   'song_name': 'PYTHON FUNK',
#   'duration_ms': 74285,
#   'url': 'https://open.spotify.com/track/4YvxfQF9QCXykqi2ahREC4',
#   'popularity': 73,
#   'song_added': '2025-03-07T07:59:49Z',
#   'album_id': '7JslfZtjZ430btdARyxLQ4',
#   'artist_id': '62D4KEvQMmmK88mTkkWx6Q'},
#  {'song_id': '0RVmg31gzlshCm356g0HF2',
#   'song_name': 'BAIXO',
#   'duration_ms': 104013,
#   'url': 'https://open.spotify.com/track/0RVmg31gzlshCm356g0HF2',
#   'popularity': 69,
#   'song_added': '2025-03-07T07:59:54Z',
#   'album_id': '2Osz2h7ZjKHOZh5grL7o6G',
#   'artist_id': '4nl0CCx6PpEOOr2Z2ThPdp'},
#  {'song_id': '2V3hsJU3bTOATih0Fm4aDp',
#   'song_name': 'BRODYAGA FUNK',
#   'duration_ms': 134785,
#   'url': 'https://open.spotify.com/track/2V3hsJU3bTOATih0Fm4aDp',
#   'popularity': 78,
#   'song_added': '2025-03-07T08:00:05Z',
#   'album_id': '7EWDvEG6vKIjTBk3rGMtP0',
#   'artist_id': '3Xd2WSaNywx5gn1pgRPFjF'},
#  {'song_id': '6fxeXlCSt4WLVlbqxgUBMB',
#   'song_name': 'Funk of Galáctico',
#   'duration_ms': 90461,
#   'url': 'https://open.spotify.com/track/6fxeXlCSt4WLVlbqxgUBMB',
#   'popularity': 78,
#   'song_added': '2025-03-07T08:02:15Z',
#   'album_id': '0cpfgDzjHZuYfiBc7jPsn6',
#   'artist_id': '3eTy7yvRHnpPKY4hNCfYYX'},
#  {'song_id': '5hL2t5WyC9bibNDVkhVvDx',
#   'song_name': 'NEXT!',
#   'duration_ms': 99692,
#   'url': 'https://open.spotify.com/track/5hL2t5WyC9bibNDVkhVvDx',
#   'popularity': 81,
#   'song_added': '2025-03-07T08:02:31Z',
#   'album_id': '1k9oQsBjwIhc4vF32zxvY5',
#   'artist_id': '6BWtcMF39LT5Db5FT54YYG'},
#  {'song_id': '4hcnbu7PdISGGj82ZuDpFQ',
#   'song_name': 'FRESH',
#   'duration_ms': 68687,
#   'url': 'https://open.spotify.com/track/4hcnbu7PdISGGj82ZuDpFQ',
#   'popularity': 69,
#   'song_added': '2025-03-07T08:02:46Z',
#   'album_id': '5eRHyCycBt78BNaa8vR4Si',
#   'artist_id': '4f0duKhSmQubrgvVjUAKvh'},
#  {'song_id': '32aXDvXy4eYqQnXfD9pbh9',
#   'song_name': 'MONTAGEM BRAVO - Slowed',
#   'duration_ms': 91906,
#   'url': 'https://open.spotify.com/track/32aXDvXy4eYqQnXfD9pbh9',
#   'popularity': 75,
#   'song_added': '2025-03-07T08:02:50Z',
#   'album_id': '2RhX80u97LacDUbFoSLT5W',
#   'artist_id': '5tIkxADHN80ca0K6HCpWIt'},
#  {'song_id': '7bxyNLXYaEYaZTxAuQTHlD',
#   'song_name': 'TUCA DONKA',
#   'duration_ms': 75692,
#   'url': 'https://open.spotify.com/track/7bxyNLXYaEYaZTxAuQTHlD',
#   'popularity': 76,
#   'song_added': '2025-03-07T08:02:58Z',
#   'album_id': '27XmqsKeLyr5jDURAordcd',
#   'artist_id': '6rzNFUmaEVnYb8kzh9tBTt'},
#  {'song_id': '7hcagAQDiI0TgUOv337NIr',
#   'song_name': 'Orquestra Maldita',
#   'duration_ms': 119777,
#   'url': 'https://open.spotify.com/track/7hcagAQDiI0TgUOv337NIr',
#   'popularity': 73,
#   'song_added': '2025-03-07T08:03:02Z',
#   'album_id': '6DptPhwLku8xvWBodULnC6',
#   'artist_id': '3rt96VXGtEgD4uSOJ6B69H'},
#  {'song_id': '3i6tlvYU1BSAM3yGQNemtM',
#   'song_name': 'DNA',
#   'duration_ms': 88740,
#   'url': 'https://open.spotify.com/track/3i6tlvYU1BSAM3yGQNemtM',
#   'popularity': 75,
#   'song_added': '2025-03-07T08:03:06Z',
#   'album_id': '1ILssfrknV8cQv5QvwBGUY',
#   'artist_id': '5IpS1TN1Crp8Ym4zjiIrtK'},
#  {'song_id': '38dHd7r4mSSVhRvVulD1na',
#   'song_name': 'SPACE! - Super Slowed',
#   'duration_ms': 109848,
#   'url': 'https://open.spotify.com/track/38dHd7r4mSSVhRvVulD1na',
#   'popularity': 76,
#   'song_added': '2025-03-07T08:03:13Z',
#   'album_id': '6tf2ziKDZQJinItJi99wBW',
#   'artist_id': '5AviPhK4XqgGjtTa0m9aQc'},
#  {'song_id': '0hEjvk5rMwLzt9rUcFmZG7',
#   'song_name': 'Sequência da Dz7',
#   'duration_ms': 119231,
#   'url': 'https://open.spotify.com/track/0hEjvk5rMwLzt9rUcFmZG7',
#   'popularity': 71,
#   'song_added': '2025-03-07T08:03:17Z',
#   'album_id': '3BsuqyYCV0DYIBrDi1SKwQ',
#   'artist_id': '3rt96VXGtEgD4uSOJ6B69H'},
#  {'song_id': '7vtGOauV0Zz8Px5EJYm7d7',
#   'song_name': 'Life in Rio',
#   'duration_ms': 94418,
#   'url': 'https://open.spotify.com/track/7vtGOauV0Zz8Px5EJYm7d7',
#   'popularity': 71,
#   'song_added': '2025-03-07T08:03:21Z',
#   'album_id': '2EuOCirl08WxbRY2cfj4H5',
#   'artist_id': '65FHTCI8EmW94W0TdWb8ja'},
#  {'song_id': '4aMdNP3vuboq7t8BPZ4rE1',
#   'song_name': 'Turu R9 - Slowed',
#   'duration_ms': 78710,
#   'url': 'https://open.spotify.com/track/4aMdNP3vuboq7t8BPZ4rE1',
#   'popularity': 68,
#   'song_added': '2025-03-07T08:07:02Z',
#   'album_id': '7cNqBJdXx8dgoXegihUPVN',
#   'artist_id': '21zPGluD0MD68ctSgkuMXi'},
#  {'song_id': '56BZSVROHDzuiYM8C2Zv3y',
#   'song_name': 'FUNK INFERNAL',
#   'duration_ms': 90000,
#   'url': 'https://open.spotify.com/track/56BZSVROHDzuiYM8C2Zv3y',
#   'popularity': 79,
#   'song_added': '2025-03-07T08:07:21Z',
#   'album_id': '3Iw0jAPzwgmuqSIWQa9i8W',
#   'artist_id': '6ZhleMHIGIpjkBHrQDl4G7'},
#  {'song_id': '5aKBB7hzLwe2B9DCGoUokj',
#   'song_name': 'Montagem Sonic Ritmado 1.0 (Slowed)',
#   'duration_ms': 92225,
#   'url': 'https://open.spotify.com/track/5aKBB7hzLwe2B9DCGoUokj',
#   'popularity': 56,
#   'song_added': '2025-03-07T08:07:43Z',
#   'album_id': '6la9ubAAPlhP8eylFPuLlC',
#   'artist_id': '5WqZHtRzOmKc1hWYfNoo8n'},
#  {'song_id': '1T09ARjY1LkuSJVJTk100T',
#   'song_name': 'Montagem Injuriosum Retines - Slowed',
#   'duration_ms': 151632,
#   'url': 'https://open.spotify.com/track/1T09ARjY1LkuSJVJTk100T',
#   'popularity': 63,
#   'song_added': '2025-03-07T08:07:49Z',
#   'album_id': '1R1KJCX1oc3xqSbABo2Wpn',
#   'artist_id': '07MaeHw0cyfmgQ9D9I61UT'},
#  {'song_id': '1D9xlpo9gGhLWrHz0APRlJ',
#   'song_name': 'Automotivo da Turbulencia',
#   'duration_ms': 132922,
#   'url': 'https://open.spotify.com/track/1D9xlpo9gGhLWrHz0APRlJ',
#   'popularity': 77,
#   'song_added': '2025-03-07T08:07:55Z',
#   'album_id': '1mEN4vjqXeZN9FmNzFLCBf',
#   'artist_id': '0LyfQWJT6nXafLPZqxe9Of'},
#  {'song_id': '1XBarxRIZkpNzIqj2IlIMe',
#   'song_name': 'Funk Secreto - Ultra Slowed',
#   'duration_ms': 89773,
#   'url': 'https://open.spotify.com/track/1XBarxRIZkpNzIqj2IlIMe',
#   'popularity': 70,
#   'song_added': '2025-03-07T08:08:01Z',
#   'album_id': '2bqWrlHmNh4M41xOr0p7iN',
#   'artist_id': '0exQbKNFd9pLmdIGycwmlf'},
#  {'song_id': '4Pxm8GR4lQT1WnhvN2qNvx',
#   'song_name': 'void - super slowed',
#   'duration_ms': 101420,
#   'url': 'https://open.spotify.com/track/4Pxm8GR4lQT1WnhvN2qNvx',
#   'popularity': 77,
#   'song_added': '2025-03-07T08:08:06Z',
#   'album_id': '3HEJNpi4OtYpYQlGy2anVB',
#   'artist_id': '6JjQbtAO09K7qBEW2pdX5s'},
#  {'song_id': '6zNJ6JW1Ov5qERrsC3mfeu',
#   'song_name': 'FUNK ESTRANHO - SUPER SLOWED',
#   'duration_ms': 150186,
#   'url': 'https://open.spotify.com/track/6zNJ6JW1Ov5qERrsC3mfeu',
#   'popularity': 66,
#   'song_added': '2025-03-07T08:08:10Z',
#   'album_id': '74uo4Lv0VMyxdOjlf40y1T',
#   'artist_id': '3Ng2KitKkpjyym1V03mV00'},
#  {'song_id': '6ISgjQNYq70ahUOL9rOrcz',
#   'song_name': 'BLUE HORIZON FUNK - SLOWED',
#   'duration_ms': 85642,
#   'url': 'https://open.spotify.com/track/6ISgjQNYq70ahUOL9rOrcz',
#   'popularity': 77,
#   'song_added': '2025-03-07T08:08:14Z',
#   'album_id': '5jXbkZ8fgtvq5OufR9LJz4',
#   'artist_id': '7lAaAGxYxk2GH8cMbTEwAL'},
#  {'song_id': '5kfzt2xCxOCrmt1H6H2d8O',
#   'song_name': 'BLAH',
#   'duration_ms': 141641,
#   'url': 'https://open.spotify.com/track/5kfzt2xCxOCrmt1H6H2d8O',
#   'popularity': 39,
#   'song_added': '2025-03-07T08:08:19Z',
#   'album_id': '7hNzImuUou9dBftesPXcAt',
#   'artist_id': '4H61c3XQu4PswXGtB0MJ6N'},
#  {'song_id': '52uQ2fQqo9hX5H4p7Niq0b',
#   'song_name': 'DON`T STOP - Slowed',
#   'duration_ms': 179904,
#   'url': 'https://open.spotify.com/track/52uQ2fQqo9hX5H4p7Niq0b',
#   'popularity': 77,
#   'song_added': '2025-03-07T08:18:37Z',
#   'album_id': '1Idktx9vdSSkm1yxABycnf',
#   'artist_id': '5Vd9shhZpzTYaaZ6KQNnjU'},
#  {'song_id': '67smGwuPEtA6GAfeweAVNO',
#   'song_name': 'SLAY!',
#   'duration_ms': 107076,
#   'url': 'https://open.spotify.com/track/67smGwuPEtA6GAfeweAVNO',
#   'popularity': 82,
#   'song_added': '2025-03-07T08:18:44Z',
#   'album_id': '3xCc8FxQsm6AE7ZWJ7h5sx',
#   'artist_id': '3Xd2WSaNywx5gn1pgRPFjF'},
#  {'song_id': '2b9JG7m7tvwHONER43us1n',
#   'song_name': 'MONTAGEM INVASÃO',
#   'duration_ms': 74769,
#   'url': 'https://open.spotify.com/track/2b9JG7m7tvwHONER43us1n',
#   'popularity': 67,
#   'song_added': '2025-03-07T08:18:49Z',
#   'album_id': '5rl2NDQDv9VpZLoEFOaYNg',
#   'artist_id': '3c4ngCW3y8USmyrjRdB1mG'},
#  {'song_id': '5HeZquObI5L19NEDL8KnIc',
#   'song_name': 'BRUXO FANTASMA - SUPER SLOWED',
#   'duration_ms': 113058,
#   'url': 'https://open.spotify.com/track/5HeZquObI5L19NEDL8KnIc',
#   'popularity': 74,
#   'song_added': '2025-03-07T08:19:02Z',
#   'album_id': '09xRsRc7pX399wCGElOfMT',
#   'artist_id': '5IpS1TN1Crp8Ym4zjiIrtK'},
#  {'song_id': '7IVstMaDl2HaByG8JmR2yr',
#   'song_name': 'Montagem Lunar Celestia 1.0 (SLOWED)',
#   'duration_ms': 96254,
#   'url': 'https://open.spotify.com/track/7IVstMaDl2HaByG8JmR2yr',
#   'popularity': 81,
#   'song_added': '2025-03-07T08:19:13Z',
#   'album_id': '5tod76GzFMGREffztRiLyJ',
#   'artist_id': '5WqZHtRzOmKc1hWYfNoo8n'},
#  {'song_id': '02WKo37gebkkQKor2TCuTk',
#   'song_name': 'Beeper Funk - Slowed',
#   'duration_ms': 103375,
#   'url': 'https://open.spotify.com/track/02WKo37gebkkQKor2TCuTk',
#   'popularity': 73,
#   'song_added': '2025-03-07T08:19:20Z',
#   'album_id': '5eEfzNcFaXPsBXJzkPiD3S',
#   'artist_id': '648ZoUpTM6iIMTCgo3lLCE'},
#  {'song_id': '5Nk4wgj4fmvue8sCs2kSlX',
#   'song_name': 'FUNK DO BALKAN - Slowed',
#   'duration_ms': 81336,
#   'url': 'https://open.spotify.com/track/5Nk4wgj4fmvue8sCs2kSlX',
#   'popularity': 70,
#   'song_added': '2025-03-07T08:19:39Z',
#   'album_id': '6PZBt4XZvd1ElHAHG31J1j',
#   'artist_id': '60vF1fLR6yzLxCQUlnAYYj'},
#  {'song_id': '28Qri8CIMxJUQauS8YOR7o',
#   'song_name': 'Ela Vira Mortal',
#   'duration_ms': 136370,
#   'url': 'https://open.spotify.com/track/28Qri8CIMxJUQauS8YOR7o',
#   'popularity': 70,
#   'song_added': '2025-03-07T08:19:45Z',
#   'album_id': '05EQpLFKhJ1m4YElm4zDHr',
#   'artist_id': '1yTrrABG9Vr2Y9lbHupN3f'},
#  {'song_id': '6AYTqLO7dw1h212u5zqjPz',
#   'song_name': 'O Melhor no Que Faz 3.0',
#   'duration_ms': 120240,
#   'url': 'https://open.spotify.com/track/6AYTqLO7dw1h212u5zqjPz',
#   'popularity': 64,
#   'song_added': '2025-03-07T08:37:29Z',
#   'album_id': '2R1AMmWGUa5IJYAdejtajq',
#   'artist_id': '19P1EvDdYzg1ICEyiAEk4m'},
#  {'song_id': '70FceppUZq9dQz1mDPcHcs',
#   'song_name': 'Death Is No More',
#   'duration_ms': 138500,
#   'url': 'https://open.spotify.com/track/70FceppUZq9dQz1mDPcHcs',
#   'popularity': 71,
#   'song_added': '2025-03-07T08:37:35Z',
#   'album_id': '5Ide1hRSwzUYUnTQhq6CBv',
#   'artist_id': '4RsEAdLhbUy7j3zHWauPwF'},
#  {'song_id': '1v5PQyuSHxPy56xCuCnMQ0',
#   'song_name': 'SEQUÊNCIA MALÉFICA 1.0',
#   'duration_ms': 96461,
#   'url': 'https://open.spotify.com/track/1v5PQyuSHxPy56xCuCnMQ0',
#   'popularity': 68,
#   'song_added': '2025-03-07T08:37:40Z',
#   'album_id': '4Fpr7mZ709qg0Iu1ESYNwz',
#   'artist_id': '5joODcLQTClX0o3q13SOfU'},
#  {'song_id': '0R902FnwJO8kBZYvtpQLrL',
#   'song_name': 'YUM YUM',
#   'duration_ms': 129697,
#   'url': 'https://open.spotify.com/track/0R902FnwJO8kBZYvtpQLrL',
#   'popularity': 69,
#   'song_added': '2025-03-07T08:37:45Z',
#   'album_id': '7Bc7xEWvkW01bvq5jAhCQS',
#   'artist_id': '5IpS1TN1Crp8Ym4zjiIrtK'},
#  {'song_id': '6kJjlOWBwnDwIBsvlwTNIF',
#   'song_name': 'BAD PARENTING FUNK',
#   'duration_ms': 87834,
#   'url': 'https://open.spotify.com/track/6kJjlOWBwnDwIBsvlwTNIF',
#   'popularity': 76,
#   'song_added': '2025-03-07T08:37:49Z',
#   'album_id': '2DNOGCn0szoh9f3rAnhF7b',
#   'artist_id': '1iKfUld50BOVBIgHy3GlGt'},
#  {'song_id': '2NVY5DJmbIxMr0a4glhyHU',
#   'song_name': 'Cuando se te moja la tarea 2',
#   'duration_ms': 179302,
#   'url': 'https://open.spotify.com/track/2NVY5DJmbIxMr0a4glhyHU',
#   'popularity': 70,
#   'song_added': '2025-03-07T08:37:53Z',
#   'album_id': '5hUTWbVLPE7Vo9KtS06U15',
#   'artist_id': '2DtIt7mMzdaEEFVUbSmnoU'},
#  {'song_id': '1lS2qOUk6GA20XvjjrWc25',
#   'song_name': 'MANDA BALA',
#   'duration_ms': 100465,
#   'url': 'https://open.spotify.com/track/1lS2qOUk6GA20XvjjrWc25',
#   'popularity': 72,
#   'song_added': '2025-03-07T08:38:02Z',
#   'album_id': '4ibsk1iPM7xDpJkNXREmsl',
#   'artist_id': '09cKncAQn28NqTUORLMwSR'},
#  {'song_id': '4Ha6W6v9DSTecYYtovtvg7',
#   'song_name': 'FUNK OSCURO - Super Slowed',
#   'duration_ms': 120000,
#   'url': 'https://open.spotify.com/track/4Ha6W6v9DSTecYYtovtvg7',
#   'popularity': 68,
#   'song_added': '2025-03-07T08:38:06Z',
#   'album_id': '4hBpayDWGOGsgnwFY8qm3G',
#   'artist_id': '0exQbKNFd9pLmdIGycwmlf'},
#  {'song_id': '1AjFAmF0qkMSSzDrXykwes',
#   'song_name': 'Montagem Bionica Espectral 2 (Slowed + Reverb)',
#   'duration_ms': 109176,
#   'url': 'https://open.spotify.com/track/1AjFAmF0qkMSSzDrXykwes',
#   'popularity': 61,
#   'song_added': '2025-03-07T08:38:11Z',
#   'album_id': '5NJDkJdeVRTLpOJalNfb95',
#   'artist_id': '1cCYuIofJkQf9YN1FZo5A4'},
#  {'song_id': '2iRiWUoB7tNnG23KlM3Ui7',
#   'song_name': 'RISADA CHUCK 01 - Super Slowed',
#   'duration_ms': 130360,
#   'url': 'https://open.spotify.com/track/2iRiWUoB7tNnG23KlM3Ui7',
#   'popularity': 73,
#   'song_added': '2025-03-07T08:38:27Z',
#   'album_id': '7lolzbhq4moSJPfFpdosl5',
#   'artist_id': '3uA4unR7LBOcqjpbOeCs0Y'},
#  {'song_id': '1aNQ9Nz0gzJXVm6kuXcIbq',
#   'song_name': 'ACIDO',
#   'duration_ms': 75697,
#   'url': 'https://open.spotify.com/track/1aNQ9Nz0gzJXVm6kuXcIbq',
#   'popularity': 76,
#   'song_added': '2025-03-07T08:44:29Z',
#   'album_id': '47VSbmVnuMFiaFv3ZiK0Ee',
#   'artist_id': '6ESoeEazu57neU7UM6KRuC'},
#  {'song_id': '0RgKtaVv27Nff2y29qaD8W',
#   'song_name': 'ICEWHORE!',
#   'duration_ms': 79052,
#   'url': 'https://open.spotify.com/track/0RgKtaVv27Nff2y29qaD8W',
#   'popularity': 67,
#   'song_added': '2025-03-07T08:44:35Z',
#   'album_id': '5J00ADHG1jlJiLjQDPURVh',
#   'artist_id': '1TTHC3GlNDaE5eVoC3BVxm'},
#  {'song_id': '6vEOZGTBgE6gASrzAWNxTH',
#   'song_name': 'MONTAGEM DIAMANTE ROSA',
#   'duration_ms': 99692,
#   'url': 'https://open.spotify.com/track/6vEOZGTBgE6gASrzAWNxTH',
#   'popularity': 66,
#   'song_added': '2025-03-07T08:44:41Z',
#   'album_id': '28N1pcdMLhrEajfJKkBkl1',
#   'artist_id': '3yn6fs9MkW1i4V3S2G8Dxs'},
#  {'song_id': '7yIwT8zSR8dzl0rWXbW2jm',
#   'song_name': 'MTG - VINGANÇA',
#   'duration_ms': 75692,
#   'url': 'https://open.spotify.com/track/7yIwT8zSR8dzl0rWXbW2jm',
#   'popularity': 63,
#   'song_added': '2025-03-07T08:44:46Z',
#   'album_id': '7DGsEVuwdKBKrzDx8fzEKn',
#   'artist_id': '3QMpCp3GHiHXgnX1LldXWe'},
#  {'song_id': '25MzUGleMnmyoeTNRZ8QF1',
#   'song_name': 'VAPO NO SETOR',
#   'duration_ms': 67596,
#   'url': 'https://open.spotify.com/track/25MzUGleMnmyoeTNRZ8QF1',
#   'popularity': 78,
#   'song_added': '2025-03-07T08:44:52Z',
#   'album_id': '6h4Lw0QisEuuAwmnMQvbse',
#   'artist_id': '3wQNcarvRuzhz2Fg1pVDxZ'},
#  {'song_id': '1ytfbcVbSMHIgzijgt4z2e',
#   'song_name': 'BIBI PHONK BR',
#   'duration_ms': 119616,
#   'url': 'https://open.spotify.com/track/1ytfbcVbSMHIgzijgt4z2e',
#   'popularity': 66,
#   'song_added': '2025-03-07T08:44:56Z',
#   'album_id': '4cfBuRZw1az5lIdTYxuOPq',
#   'artist_id': '6R26kGib2ubbZJMh7kKVGV'},
#  {'song_id': '2CSQju5oDh0zMIwsf6qcsN',
#   'song_name': 'x-tudo - slowed',
#   'duration_ms': 75611,
#   'url': 'https://open.spotify.com/track/2CSQju5oDh0zMIwsf6qcsN',
#   'popularity': 64,
#   'song_added': '2025-03-07T08:45:01Z',
#   'album_id': '5mGMCvuF70Alfy0FXg3Sn7',
#   'artist_id': '1M02J1PLobtQYok93DEvVa'},
#  {'song_id': '6cDMNTlXoInwCg5Jo0Nd4F',
#   'song_name': 'AREAMATE MIZ',
#   'duration_ms': 76375,
#   'url': 'https://open.spotify.com/track/6cDMNTlXoInwCg5Jo0Nd4F',
#   'popularity': 63,
#   'song_added': '2025-03-07T08:45:06Z',
#   'album_id': '0VnjSeajDjzh2mRdWePGhN',
#   'artist_id': '4C5EDmZfgkkSwUVFSvuUNP'},
#  {'song_id': '3RlfkOE0lXMec08I6CaakR',
#   'song_name': 'YUMMI',
#   'duration_ms': 95996,
#   'url': 'https://open.spotify.com/track/3RlfkOE0lXMec08I6CaakR',
#   'popularity': 65,
#   'song_added': '2025-03-07T08:45:11Z',
#   'album_id': '4J0FEQtbjPH1DA60p6bKe9',
#   'artist_id': '5IpS1TN1Crp8Ym4zjiIrtK'},
#  {'song_id': '1Xvs6IKi0O1PWYzzIwxR2Q',
#   'song_name': 'WHINE IN BRAZIL FUNK',
#   'duration_ms': 107971,
#   'url': 'https://open.spotify.com/track/1Xvs6IKi0O1PWYzzIwxR2Q',
#   'popularity': 70,
#   'song_added': '2025-03-07T08:45:17Z',
#   'album_id': '6tuTOSJX2SjH8JBsh5uM30',
#   'artist_id': '6wWEEpCzvBH6Z5EVZ86wJl'},
#  {'song_id': '6gXzRzLtdNSbsJVg72J3AA',
#   'song_name': 'MONTAGEM VOZES PROFUNDAS - TikTok Version',
#   'duration_ms': 54308,
#   'url': 'https://open.spotify.com/track/6gXzRzLtdNSbsJVg72J3AA',
#   'popularity': 70,
#   'song_added': '2025-03-07T08:48:07Z',
#   'album_id': '58Uel2jPuFAf4bRiWHLYVz',
#   'artist_id': '3rX0drWPVa50yFG3HqzX0T'},
#  {'song_id': '15Fkxa5C3qNgMoLYdHJJ4z',
#   'song_name': 'Bero 02',
#   'duration_ms': 95783,
#   'url': 'https://open.spotify.com/track/15Fkxa5C3qNgMoLYdHJJ4z',
#   'popularity': 67,
#   'song_added': '2025-03-07T08:49:39Z',
#   'album_id': '5T9u88WBOgCsGk3GT30Z3r',
#   'artist_id': '4C5EDmZfgkkSwUVFSvuUNP'},
#  {'song_id': '2SQp5yapF1ZwiuKgaFuFMJ',
#   'song_name': 'Montagem Melodia Explosiva - Slowed',
#   'duration_ms': 104347,
#   'url': 'https://open.spotify.com/track/2SQp5yapF1ZwiuKgaFuFMJ',
#   'popularity': 71,
#   'song_added': '2025-03-07T08:53:20Z',
#   'album_id': '3D2j7JQjj9Kjc8sOfikmV6',
#   'artist_id': '1PvcWjADPMezv8CTyJO9Uk'},
#  {'song_id': '5VZ0soW5syQfefCUj603DW',
#   'song_name': 'MASHA ULTRAFUNK',
#   'duration_ms': 93650,
#   'url': 'https://open.spotify.com/track/5VZ0soW5syQfefCUj603DW',
#   'popularity': 74,
#   'song_added': '2025-03-18T19:45:04Z',
#   'album_id': '43DSGSYCywacjEkdeSv4DC',
#   'artist_id': '5Z56BMrvQB2rBAa5kffTPD'},
#  {'song_id': '6hZGsChumRhWG24OEh698c',
#   'song_name': 'Ela Joga na Hora',
#   'duration_ms': 132922,
#   'url': 'https://open.spotify.com/track/6hZGsChumRhWG24OEh698c',
#   'popularity': 77,
#   'song_added': '2025-03-20T11:11:33Z',
#   'album_id': '30Ytb0PG1tOv7JiKOTBK2v',
#   'artist_id': '2sQHo73pQF1OTq3lDuQhlO'},
#  {'song_id': '6yVjjQA31SLM1kc4j5jPwF',
#   'song_name': 'BRAZILIAN DANÇA PHONK',
#   'duration_ms': 118194,
#   'url': 'https://open.spotify.com/track/6yVjjQA31SLM1kc4j5jPwF',
#   'popularity': 73,
#   'song_added': '2025-03-20T11:13:22Z',
#   'album_id': '4QlnGetYxfXaVGhgdmF0vG',
#   'artist_id': '24YUNOEuu3kf4OOtC8cQE5'},
#  {'song_id': '5WMrHMfkarliApsXvwUTrh',
#   'song_name': 'z-beta 2 - Super Slowed',
#   'duration_ms': 94040,
#   'url': 'https://open.spotify.com/track/5WMrHMfkarliApsXvwUTrh',
#   'popularity': 72,
#   'song_added': '2025-03-24T23:41:07Z',
#   'album_id': '6dRJ8zaG9oTGrwpfu0Itld',
#   'artist_id': '32Pxa55IN0QAmFtzWcT2w9'},
#  {'song_id': '19xg284tQrdnm4zZGnajs0',
#   'song_name': 'Faz de Chicote',
#   'duration_ms': 150569,
#   'url': 'https://open.spotify.com/track/19xg284tQrdnm4zZGnajs0',
#   'popularity': 74,
#   'song_added': '2025-03-31T17:37:42Z',
#   'album_id': '2cuIEt1nONL2bu9HnSXjVT',
#   'artist_id': '0LyfQWJT6nXafLPZqxe9Of'},
#  {'song_id': '5smCqaAEcKpArEBVhtaryT',
#   'song_name': 'MY TYPE - Slowed',
#   'duration_ms': 91585,
#   'url': 'https://open.spotify.com/track/5smCqaAEcKpArEBVhtaryT',
#   'popularity': 69,
#   'song_added': '2025-04-05T04:13:26Z',
#   'album_id': '4yUHDMHDEl6Th3jPimciMz',
#   'artist_id': '4pmKpROq7rAVibM7qR9h6P'},
#  {'song_id': '03E0f4JneWZEtrQPU6EsIV',
#   'song_name': 'BLOODY! - ULTRA SLOWED',
#   'duration_ms': 139384,
#   'url': 'https://open.spotify.com/track/03E0f4JneWZEtrQPU6EsIV',
#   'popularity': 74,
#   'song_added': '2025-04-05T04:13:55Z',
#   'album_id': '0yr5YRR7l813mmHITxmFWa',
#   'artist_id': '1qaCszXlFNPEnCELYBixa5'}]

# %%
import pandas as pd

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id         album_name release_date  total_tracks  \
# 0  6xUYw5goKIoyJQi9C27UBy        NUNCA MUDA?   2025-01-09             6
# 1  5D17Gk0J7jPXLvWMszqijF    MONTAGEM TOMADA   2025-03-21             4
# 2  1kmsUHDC0n611meNgzRkuw      FUNK UNIVERSO   2024-07-03             4
# 3  3Aw43kkDlLE5ZXwQPGHWgO    MONTAGEM LADRAO   2025-02-05             5
# 4  62R2H85ZiKLp0lYHPprQWV  MTG - RITMO ZELDA   2024-06-28             4
#
#                                                  url
# 0  https://open.spotify.com/album/6xUYw5goKIoyJQi...
# 1  https://open.spotify.com/album/5D17Gk0J7jPXLvW...
# 2  https://open.spotify.com/album/1kmsUHDC0n611me...
# 3  https://open.spotify.com/album/3Aw43kkDlLE5ZXw...
# 4  https://open.spotify.com/album/62R2H85ZiKLp0lY...

# %%
artist_df = pd.DataFrame.from_dict(artist_list)
artist_df.head()
# Out:
#                 artist_id        artist_name  \
# 0  5dDNNq04RjKXFOADdHd6VX        Scythermane
# 1  7lAaAGxYxk2GH8cMbTEwAL             NXGHT!
# 2  14hsjenLEdvafsGkk2CEiF  MC Fabinho da Osk
# 3  7kk9ucvRJim0NMM89Lml2Y               MXZI
# 4  2vKxv2oKVSEJZ1VmuLUOvY              Irokz
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/5dDNNq04RjK...
# 1  https://api.spotify.com/v1/artists/7lAaAGxYxk2...
# 2  https://api.spotify.com/v1/artists/14hsjenLEdv...
# 3  https://api.spotify.com/v1/artists/7kk9ucvRJim...
# 4  https://api.spotify.com/v1/artists/2vKxv2oKVSE...

# %%
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df.head()
# Out:
#                   song_id                         song_name  duration_ms  \
# 0  5EIjpM1B1VsLoKvv2iwd0P                       NUNCA MUDA?        81500
# 1  1mfvWzF39LwVpAm8g0LhQT          MONTAGEM TOMADA - Slowed        84901
# 2  466x7CJlVwiFdNTLvIXwZl                     FUNK UNIVERSO       127500
# 3  48WnIIBbnttcwUQ77MBoMI                   MONTAGEM LADRAO        75240
# 4  5XwNsUvJxk38263zeXrfXI  MTG - RITMO ZELDA - Super Slowed       107093
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/5EIjpM1B1VsLoKv...          86
# 1  https://open.spotify.com/track/1mfvWzF39LwVpAm...          81
# 2  https://open.spotify.com/track/466x7CJlVwiFdNT...          78
# 3  https://open.spotify.com/track/48WnIIBbnttcwUQ...          82
# 4  https://open.spotify.com/track/5XwNsUvJxk38263...          75
#
#              song_added                album_id               artist_id
# 0  2025-03-07T07:49:17Z  6xUYw5goKIoyJQi9C27UBy  5dDNNq04RjKXFOADdHd6VX
# 1  2025-04-10T07:43:26Z  5D17Gk0J7jPXLvWMszqijF  7kk9ucvRJim0NMM89Lml2Y
# 2  2025-03-07T07:49:36Z  1kmsUHDC0n611meNgzRkuw  2vKxv2oKVSEJZ1VmuLUOvY
# 3  2025-04-01T18:18:31Z  3Aw43kkDlLE5ZXwQPGHWgO  5SCDfg1YoEfI5gFtXqEWah
# 4  2025-03-20T11:10:50Z  62R2H85ZiKLp0lYHPprQWV  2nGwC9QG6Hpw4fSDgNpn5n

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91 entries, 0 to 90
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      91 non-null     object
#  1   album_name    91 non-null     object
#  2   release_date  91 non-null     object
#  3   total_tracks  91 non-null     int64
#  4   url           91 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 3.7+ KB

# %%
album_df=album_df.drop_duplicates(subset=['album_id'])

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
song_df = song_df.drop_duplicates(subset=['song_id'])

# %%
album_df.head()
# Out:
#                  album_id         album_name release_date  total_tracks  \
# 0  6xUYw5goKIoyJQi9C27UBy        NUNCA MUDA?   2025-01-09             6
# 1  5D17Gk0J7jPXLvWMszqijF    MONTAGEM TOMADA   2025-03-21             4
# 2  1kmsUHDC0n611meNgzRkuw      FUNK UNIVERSO   2024-07-03             4
# 3  3Aw43kkDlLE5ZXwQPGHWgO    MONTAGEM LADRAO   2025-02-05             5
# 4  62R2H85ZiKLp0lYHPprQWV  MTG - RITMO ZELDA   2024-06-28             4
#
#                                                  url
# 0  https://open.spotify.com/album/6xUYw5goKIoyJQi...
# 1  https://open.spotify.com/album/5D17Gk0J7jPXLvW...
# 2  https://open.spotify.com/album/1kmsUHDC0n611me...
# 3  https://open.spotify.com/album/3Aw43kkDlLE5ZXw...
# 4  https://open.spotify.com/album/62R2H85ZiKLp0lY...

# %%
artist_df.head()
# Out:
#                 artist_id        artist_name  \
# 0  5dDNNq04RjKXFOADdHd6VX        Scythermane
# 1  7lAaAGxYxk2GH8cMbTEwAL             NXGHT!
# 2  14hsjenLEdvafsGkk2CEiF  MC Fabinho da Osk
# 3  7kk9ucvRJim0NMM89Lml2Y               MXZI
# 4  2vKxv2oKVSEJZ1VmuLUOvY              Irokz
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/5dDNNq04RjK...
# 1  https://api.spotify.com/v1/artists/7lAaAGxYxk2...
# 2  https://api.spotify.com/v1/artists/14hsjenLEdv...
# 3  https://api.spotify.com/v1/artists/7kk9ucvRJim...
# 4  https://api.spotify.com/v1/artists/2vKxv2oKVSE...

# %%
song_df.head()
# Out:
#                   song_id                         song_name  duration_ms  \
# 0  5EIjpM1B1VsLoKvv2iwd0P                       NUNCA MUDA?        81500
# 1  1mfvWzF39LwVpAm8g0LhQT          MONTAGEM TOMADA - Slowed        84901
# 2  466x7CJlVwiFdNTLvIXwZl                     FUNK UNIVERSO       127500
# 3  48WnIIBbnttcwUQ77MBoMI                   MONTAGEM LADRAO        75240
# 4  5XwNsUvJxk38263zeXrfXI  MTG - RITMO ZELDA - Super Slowed       107093
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/5EIjpM1B1VsLoKv...          86
# 1  https://open.spotify.com/track/1mfvWzF39LwVpAm...          81
# 2  https://open.spotify.com/track/466x7CJlVwiFdNT...          78
# 3  https://open.spotify.com/track/48WnIIBbnttcwUQ...          82
# 4  https://open.spotify.com/track/5XwNsUvJxk38263...          75
#
#              song_added                album_id               artist_id
# 0  2025-03-07T07:49:17Z  6xUYw5goKIoyJQi9C27UBy  5dDNNq04RjKXFOADdHd6VX
# 1  2025-04-10T07:43:26Z  5D17Gk0J7jPXLvWMszqijF  7kk9ucvRJim0NMM89Lml2Y
# 2  2025-03-07T07:49:36Z  1kmsUHDC0n611meNgzRkuw  2vKxv2oKVSEJZ1VmuLUOvY
# 3  2025-04-01T18:18:31Z  3Aw43kkDlLE5ZXwQPGHWgO  5SCDfg1YoEfI5gFtXqEWah
# 4  2025-03-20T11:10:50Z  62R2H85ZiKLp0lYHPprQWV  2nGwC9QG6Hpw4fSDgNpn5n

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 91 entries, 0 to 90
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      91 non-null     object
#  1   album_name    91 non-null     object
#  2   release_date  91 non-null     datetime64[ns]
#  3   total_tracks  91 non-null     int64
#  4   url           91 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 4.3+ KB

# %%
song_df['song_added'] = pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 91 entries, 0 to 90
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      91 non-null     object
#  1   song_name    91 non-null     object
#  2   duration_ms  91 non-null     int64
#  3   url          91 non-null     object
#  4   popularity   91 non-null     int64
#  5   song_added   91 non-null     datetime64[ns, UTC]
#  6   album_id     91 non-null     object
#  7   artist_id    91 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 6.4+ KB

# %%
song_df.head()
# Out:
#                   song_id                         song_name  duration_ms  \
# 0  5EIjpM1B1VsLoKvv2iwd0P                       NUNCA MUDA?        81500
# 1  1mfvWzF39LwVpAm8g0LhQT          MONTAGEM TOMADA - Slowed        84901
# 2  466x7CJlVwiFdNTLvIXwZl                     FUNK UNIVERSO       127500
# 3  48WnIIBbnttcwUQ77MBoMI                   MONTAGEM LADRAO        75240
# 4  5XwNsUvJxk38263zeXrfXI  MTG - RITMO ZELDA - Super Slowed       107093
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/5EIjpM1B1VsLoKv...          86
# 1  https://open.spotify.com/track/1mfvWzF39LwVpAm...          81
# 2  https://open.spotify.com/track/466x7CJlVwiFdNT...          78
# 3  https://open.spotify.com/track/48WnIIBbnttcwUQ...          82
# 4  https://open.spotify.com/track/5XwNsUvJxk38263...          75
#
#                  song_added                album_id               artist_id
# 0 2025-03-07 07:49:17+00:00  6xUYw5goKIoyJQi9C27UBy  5dDNNq04RjKXFOADdHd6VX
# 1 2025-04-10 07:43:26+00:00  5D17Gk0J7jPXLvWMszqijF  7kk9ucvRJim0NMM89Lml2Y
# 2 2025-03-07 07:49:36+00:00  1kmsUHDC0n611meNgzRkuw  2vKxv2oKVSEJZ1VmuLUOvY
# 3 2025-04-01 18:18:31+00:00  3Aw43kkDlLE5ZXwQPGHWgO  5SCDfg1YoEfI5gFtXqEWah
# 4 2025-03-20 11:10:50+00:00  62R2H85ZiKLp0lYHPprQWV  2nGwC9QG6Hpw4fSDgNpn5n

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 91 entries, 0 to 90
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      91 non-null     object
#  1   album_name    91 non-null     object
#  2   release_date  91 non-null     datetime64[ns]
#  3   total_tracks  91 non-null     int64
#  4   url           91 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 4.3+ KB

# %%
artist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 136 entries, 0 to 181
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   artist_id     136 non-null    object
#  1   artist_name   136 non-null    object
#  2   external_url  136 non-null    object
# dtypes: object(3)
# memory usage: 4.2+ KB

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 91 entries, 0 to 90
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      91 non-null     object
#  1   song_name    91 non-null     object
#  2   duration_ms  91 non-null     int64
#  3   url          91 non-null     object
#  4   popularity   91 non-null     int64
#  5   song_added   91 non-null     datetime64[ns, UTC]
#  6   album_id     91 non-null     object
#  7   artist_id    91 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 6.4+ KB
